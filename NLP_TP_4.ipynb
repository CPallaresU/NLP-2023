# %%
import random
import io
import pickle

import numpy as np
import pandas as pd

from tensorflow import keras
from tensorflow.keras import layers
from keras.utils.np_utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense, LSTM, Embedding, Dropout

# %% [markdown]
# ### Datos
# Utilizaremos como dataset canciones de bandas de habla inglés.

# %%
# Armar el dataset utilizando salto de línea para separar las oraciones/docs
df = pd.read_csv('the_call_of_cthulhu.txt', sep='/n', header=None)
df.head()
# Out:
# <ipython-input-50-f6e77ae22c8d>:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv('the_call_of_cthulhu.txt', sep='/n', header=None)
#                                                    0
# 0  'THE CALL OF CTHULHU By H.P. LOVECRAFT THE CAL...

# %%
print("Cantidad de documentos:", df.shape[0])
# Out:
# Cantidad de documentos: 1

# %% [markdown]
# ### 1 - Ejemplo de Preprocesamiento
# - Hay que transformar las oraciones en tokens.
# - Dichas oraciones hay que ajustarlas al tamaño fijo de nuestra sentencia de entrada al modelo.
# - Hay que separar las palabras objetivos (target) que el modelo debe predecir en cada sentencia armada.

# %%
from keras.preprocessing.text import Tokenizer # equivalente a ltokenizer de nltk
from keras.preprocessing.text import text_to_word_sequence # equivalente a word_teokenize de nltk
from tensorflow.keras.preprocessing.sequence import pad_sequences

# largo de la secuencia, incluye seq input + word output
train_len = 4

# %%
# Ejemplo de como transformar una oración a tokens usando keras
text = df.loc[0,0]
text
# Out:
# '\'THE CALL OF CTHULHU By H.P. LOVECRAFT THE CALL OF CTHULHU Of such great powers or beings there may be conceivably a survival... a survival of a hugely remote period when... consciousness was manifested, perhaps, in shapes and forms long since withdrawn before the tide of advancing humanity... forms of which poetry and legend alone have caught a flying memory and called them gods, monsters, mythical beings of all sorts and kinds... — Algernon Blackwood PART I. THE HORROR IN CLAY The most merciful thing in the world, I think, is the inability of the human mind to correlate all its contents. We live on a placid island of ignorance in the midst of black seas of infinity, and it was not meant that we should voyage far. The sciences, each straining in its own direction, have hitherto harmed us little; but some day the piecing together of dissociated knowledge will open up such terrifying vistas of reality, and of our frightful position therein, that we shall either go mad from the revelation or flee from the light into the peace and safety of a new dark age. Theosophists have guessed at the awesome grandeur of the cosmic cycle wherein our world and human race form transient incidents. They have hinted at strange survivals in terms which would freeze the blood if not masked by a bland optimism. But it is not from them that there came the single glimpse of forbidden eons which chills me when I think of it and maddens me when I dream of it. That glimpse, like all dread glimpses of truth, flashed out from an accidental piecing together of separated things—in this case an old newspaper item and the notes of a dead professor. I hope that no one else will accomplish this piecing out; certainly, if I live, I shall never knowingly supply a link in so hideous a chain. I think that the professor, too intended to keep silent regarding the part he knew, and that he would have destroyed his notes had not sudden death seized him. My knowledge of the thing began in the winter of 1926-27 with the death of my great-uncle, George Gammell Angell, Professor Emeritus of Semitic Languages in Brown University, Providence, Rhode Island. Professor Angell was widely known as an authority on ancient inscriptions, and had frequently been resorted to by the heads of prominent museums; so that his passing at the age of ninety-two may be recalled by many. Locally, interest was intensified by the obscurity of the cause of death. The professor had been stricken whilst returning from the Newport boat; falling suddenly; as witnesses said, after having been jostled by a nautical-looking negro who had come from one of the queer dark courts on the precipitous hillside which formed a short cut from the waterfront to the deceased\\\'s home in Williams Street. Physicians were unable to find any visible disorder, but concluded after perplexed debate that some obscure lesion of the heart, induced by the brisk ascent of so steep a hill by so elderly a man, was responsible for the end. At the time I saw no reason to dissent from this dictum, but latterly I am inclined to wonder—and more than wonder. As my great-uncle\\\'s heir and executor, for he died a childless widower, I was expected to go over his papers with some thoroughness; and for that purpose moved his entire set of files and boxes to my quarters in Boston. Much of the material which I correlated will be later published by the American Archaeological Society, but there was one box which I found exceedingly puzzling, and which I felt much averse from showing to other eyes. It had been locked and I did not find the key till it occurred to me to examine the personal ring which the professor carried in his pocket. Then, indeed, I succeeded in opening it, but when I did so seemed only to be confronted by a greater and more closely locked barrier. For what could be the meaning of the queer clay bas-relief and the disjointed jottings, ramblings, and cuttings which I found? Had my uncle, in his latter years become credulo ...

# %%
tokens = text_to_word_sequence(text) # entran oraciones -> salen vectores de N posiciones (tokens)
tokens
# Out:
# ["'the",
#  'call',
#  'of',
#  'cthulhu',
#  'by',
#  'h',
#  'p',
#  'lovecraft',
#  'the',
#  'call',
#  'of',
#  'cthulhu',
#  'of',
#  'such',
#  'great',
#  'powers',
#  'or',
#  'beings',
#  'there',
#  'may',
#  'be',
#  'conceivably',
#  'a',
#  'survival',
#  'a',
#  'survival',
#  'of',
#  'a',
#  'hugely',
#  'remote',
#  'period',
#  'when',
#  'consciousness',
#  'was',
#  'manifested',
#  'perhaps',
#  'in',
#  'shapes',
#  'and',
#  'forms',
#  'long',
#  'since',
#  'withdrawn',
#  'before',
#  'the',
#  'tide',
#  'of',
#  'advancing',
#  'humanity',
#  'forms',
#  'of',
#  'which',
#  'poetry',
#  'and',
#  'legend',
#  'alone',
#  'have',
#  'caught',
#  'a',
#  'flying',
#  'memory',
#  'and',
#  'called',
#  'them',
#  'gods',
#  'monsters',
#  'mythical',
#  'beings',
#  'of',
#  'all',
#  'sorts',
#  'and',
#  'kinds',
#  '—',
#  'algernon',
#  'blackwood',
#  'part',
#  'i',
#  'the',
#  'horror',
#  'in',
#  'clay',
#  'the',
#  'most',
#  'merciful',
#  'thing',
#  'in',
#  'the',
#  'world',
#  'i',
#  'think',
#  'is',
#  'the',
#  'inability',
#  'of',
#  'the',
#  'human',
#  'mind',
#  'to',
#  'correlate',
#  'all',
#  'its',
#  'contents',
#  'we',
#  'live',
#  'on',
#  'a',
#  'placid',
#  'island',
#  'of',
#  'ignorance',
#  'in',
#  'the',
#  'midst',
#  'of',
#  'black',
#  'seas',
#  'of',
#  'infinity',
#  'and',
#  'it',
#  'was',
#  'not',
#  'meant',
#  'that',
#  'we',
#  'should',
#  'voyage',
#  'far',
#  'the',
#  'sciences',
#  'each',
#  'straining',
#  'in',
#  'its',
#  'own',
#  'direction',
#  'have',
#  'hitherto',
#  'harmed',
#  'us',
#  'little',
#  'but',
#  'some',
#  'day',
#  'the',
#  'piecing',
#  'together',
#  'of',
#  'dissociated',
#  'knowledge',
#  'will',
#  'open',
#  'up',
#  'such',
#  'terrifying',
#  'vistas',
#  'of',
#  'reality',
#  'and',
#  'of',
#  'our',
#  'frightful',
#  'position',
#  'therein',
#  'that',
#  'we',
#  'shall',
#  'either',
#  'go',
#  'mad',
#  'from',
#  'the',
#  'revelation',
#  'or',
#  'flee',
#  'from',
#  'the',
#  'light',
#  'into',
#  'the',
#  'peace',
#  'and',
#  'safety',
#  'of',
#  'a',
#  'new',
#  'dark',
#  'age',
#  'theosophists',
#  'have',
#  'guessed',
#  'at',
#  'the',
#  'awesome',
#  'grandeur',
#  'of',
#  'the',
#  'cosmic',
#  'cycle',
#  'wherein',
#  'our',
#  'world',
#  'and',
#  'human',
#  'race',
#  'form',
#  'transient',
#  'incidents',
#  'they',
#  'have',
#  'hinted',
#  'at',
#  'strange',
#  'survivals',
#  'in',
#  'terms',
#  'which',
#  'would',
#  'freeze',
#  'the',
#  'blood',
#  'if',
#  'not',
#  'masked',
#  'by',
#  'a',
#  'bland',
#  'optimism',
#  'but',
#  'it',
#  'is',
#  'not',
#  'from',
#  'them',
#  'that',
#  'there',
#  'came',
#  'the',
#  'single',
#  'glimpse',
#  'of',
#  'forbidden',
#  'eons',
#  'which',
#  'chills',
#  'me',
#  'when',
#  'i',
#  'think',
#  'of',
#  'it',
#  'and',
#  'maddens',
#  'me',
#  'when',
#  'i',
#  'dream',
#  'of',
#  'it',
#  'that',
#  'glimpse',
#  'like',
#  'all',
#  'dread',
#  'glimpses',
#  'of',
#  'truth',
#  'flashed',
#  'out',
#  'from',
#  'an',
#  'accidental',
#  'piecing',
#  'together',
#  'of',
#  'separated',
#  'things—in',
#  'this',
#  'case',
#  'an',
#  'old',
#  'newspaper',
#  'item',
#  'and',
#  'the',
#  'notes',
#  'of',
#  'a',
#  'dead',
#  'professor',
#  'i',
#  'hope',
#  'that',
#  'no',
#  'one',
#  'else',
#  'will',
#  'accomplish',
#  'this',
#  'piecing',
#  'out',
#  'certainly',
#  'if',
#  'i',
#  'live',
#  'i',
#  'shall',
#  'never',
#  'knowingly',
#  'supply',
#  'a',
#  'link',
#  'in',
#  'so',
#  'hideous',
#  'a',
#  'chain',
#  'i',
#  'think',
#  'that',
#  'the',
#  'professor',
#  'too',
#  'intended',
#  'to',
#  'keep',
#  'silent',
#  'regarding',
#  'the',
#  'part',
#  'he',
#  'knew',
#  'and',
#  'that',
#  'he',
#  'would',
#  'have',
#  'destroyed',
#  'his',
#  'notes',
#  'had',
#  'not',
#  'sudden',
#  'death',
#  'seized',
#  'him',
#  'my',
#  'knowledge',
#  'of',
#  'the',
#  'thing',
#  'began',
#  'in',
#  'the',
#  'winter',
#  'of',
#  '1926',
#  '27',
#  'with',
#  'the',
#  'death',
#  'of',
#  'my',
#  'great',
#  'uncle',
#  'george',
#  'gammell',
#  'angell',
#  'professor',
#  'emeritus',
#  'of',
#  'semitic',
#  'languages',
#  'in',
#  'brown',
#  'university',
#  'providence',
#  'rhode',
#  'island',
#  'professor',
#  'angell',
#  'was',
#  'widely',
#  'known',
#  'as',
#  'an',
#  'authority',
#  'on',
#  'ancient',
#  'inscriptions',
#  'and',
#  'had',
#  'frequently',
#  'been',
#  'resorted',
#  'to',
#  'by',
#  'the',
#  'heads',
#  'of',
#  'prominent',
#  'museums',
#  'so',
#  'that',
#  'his',
#  'passing',
#  'at',
#  'the',
#  'age',
#  'of',
#  'ninety',
#  'two',
#  'may',
#  'be',
#  'recalled',
#  'by',
#  'many',
#  'locally',
#  'interest',
#  'was',
#  'intensified',
#  'by',
#  'the',
#  'obscurity',
#  'of',
#  'the',
#  'cause',
#  'of',
#  'death',
#  'the',
#  'professor',
#  'had',
#  'been',
#  'stricken',
#  'whilst',
#  'returning',
#  'from',
#  'the',
#  'newport',
#  'boat',
#  'falling',
#  'suddenly',
#  'as',
#  'witnesses',
#  'said',
#  'after',
#  'having',
#  'been',
#  'jostled',
#  'by',
#  'a',
#  'nautical',
#  'looking',
#  'negro',
#  'who',
#  'had',
#  'come',
#  'from',
#  'one',
#  'of',
#  'the',
#  'queer',
#  'dark',
#  'courts',
#  'on',
#  'the',
#  'precipitous',
#  'hillside',
#  'which',
#  'formed',
#  'a',
#  'short',
#  'cut',
#  'from',
#  'the',
#  'waterfront',
#  'to',
#  'the',
#  'deceased',
#  "'s",
#  'home',
#  'in',
#  'williams',
#  'street',
#  'physicians',
#  'were',
#  'unable',
#  'to',
#  'find',
#  'any',
#  'visible',
#  'disorder',
#  'but',
#  'concluded',
#  'after',
#  'perplexed',
#  'debate',
#  'that',
#  'some',
#  'obscure',
#  'lesion',
#  'of',
#  'the',
#  'heart',
#  'induced',
#  'by',
#  'the',
#  'brisk',
#  'ascent',
#  'of',
#  'so',
#  'steep',
#  'a',
#  'hill',
#  'by',
#  'so',
#  'elderly',
#  'a',
#  'man',
#  'was',
#  'responsible',
#  'for',
#  'the',
#  'end',
#  'at',
#  'the',
#  'time',
#  'i',
#  'saw',
#  'no',
#  'reason',
#  'to',
#  'dissent',
#  'from',
#  'this',
#  'dictum',
#  'but',
#  'latterly',
#  'i',
#  'am',
#  'inclined',
#  'to',
#  'wonder—and',
#  'more',
#  'than',
#  'wonder',
#  'as',
#  'my',
#  'great',
#  'uncle',
#  "'s",
#  'heir',
#  'and',
#  'executor',
#  'for',
#  'he',
#  'died',
#  'a',
#  'childless',
#  'widower',
#  'i',
#  'was',
#  'expected',
#  'to',
#  'go',
#  'over',
#  'his',
#  'papers',
#  'with',
#  'some',
#  'thoroughness',
#  'and',
#  'for',
#  'that',
#  'purpose',
#  'moved',
#  'his',
#  'entire',
#  'set',
#  'of',
#  'files',
#  'and',
#  'boxes',
#  'to',
#  'my',
#  'quarters',
#  'in',
#  'boston',
#  'much',
#  'of',
#  'the',
#  'material',
#  'which',
#  'i',
#  'correlated',
#  'will',
#  'be',
#  'later',
#  'published',
#  'by',
#  'the',
#  'american',
#  'archaeological',
#  'society',
#  'but',
#  'there',
#  'was',
#  'one',
#  'box',
#  'which',
#  'i',
#  'found',
#  'exceedingly',
#  'puzzling',
#  'and',
#  'which',
#  'i',
#  'felt',
#  'much',
#  'averse',
#  'from',
#  'showing',
#  'to',
#  'other',
#  'eyes',
#  'it',
#  'had',
#  'been',
#  'locked',
#  'and',
#  'i',
#  'did',
#  'not',
#  'find',
#  'the',
#  'key',
#  'till',
#  'it',
#  'occurred',
#  'to',
#  'me',
#  'to',
#  'examine',
#  'the',
#  'personal',
#  'ring',
#  'which',
#  'the',
#  'professor',
#  'carried',
#  'in',
#  'his',
#  'pocket',
#  'then',
#  'indeed',
#  'i',
#  'succeeded',
#  'in',
#  'opening',
#  'it',
#  'but',
#  'when',
#  'i',
#  'did',
#  'so',
#  'seemed',
#  'only',
#  'to',
#  'be',
#  'confronted',
#  'by',
#  'a',
#  'greater',
#  'and',
#  'more',
#  'closely',
#  'locked',
#  'barrier',
#  'for',
#  'what',
#  'could',
#  'be',
#  'the',
#  'meaning',
#  'of',
#  'the',
#  'queer',
#  'clay',
#  'bas',
#  'relief',
#  'and',
#  'the',
#  'disjointed',
#  'jottings',
#  'ramblings',
#  'and',
#  'cuttings',
#  'which',
#  'i',
#  'found',
#  'had',
#  'my',
#  'uncle',
#  'in',
#  'his',
#  'latter',
#  'years',
#  'become',
#  'credulous',
#  'of',
#  'the',
#  'most',
#  'superficial',
#  'impostures',
#  'i',
#  'resolved',
#  'to',
#  'search',
#  'out',
#  'the',
#  'eccentric',
#  'sculptor',
#  'responsible',
#  'for',
#  'this',
#  'apparent',
#  'disturbance',
#  'of',
#  'an',
#  'old',
#  'man',
#  "'s",
#  'peace',
#  'of',
#  'mind',
#  'the',
#  'bas',
#  'relief',
#  'was',
#  'a',
#  'rough',
#  'rectangle',
#  'less',
#  'than',
#  'an',
#  'inch',
#  'thick',
#  'and',
#  'about',
#  'five',
#  'by',
#  'six',
#  'inches',
#  'in',
#  'area',
#  'obviously',
#  'of',
#  'modern',
#  'origin',
#  'its',
#  'designs',
#  'however',
#  'were',
#  'far',
#  'from',
#  'modern',
#  'in',
#  'atmosphere',
#  'and',
#  'suggestion',
#  'for',
#  'although',
#  'the',
#  'vagaries',
#  'of',
#  'cubism',
#  'and',
#  'futurism',
#  'are',
#  'many',
#  'and',
#  'wild',
#  'they',
#  'do',
#  'not',
#  'often',
#  'reproduce',
#  'that',
#  'cryptic',
#  'regularity',
#  'which',
#  'lurks',
#  'in',
#  'prehistoric',
#  'writing',
#  'and',
#  'writing',
#  'of',
#  'some',
#  'kind',
#  'the',
#  'bulk',
#  'of',
#  'these',
#  'designs',
#  'seemed',
#  'certainly',
#  'to',
#  'be',
#  'though',
#  'my',
#  'memory',
#  'despite',
#  'much',
#  'the',
#  'papers',
#  'and',
#  'collections',
#  'of',
#  'my',
#  'uncle',
#  'failed',
#  'in',
#  'any',
#  'way',
#  'to',
#  'identify',
#  'this',
#  'particular',
#  'species',
#  'or',
#  'even',
#  'hint',
#  'at',
#  'its',
#  'remotest',
#  'affiliations',
#  'above',
#  'these',
#  'apparent',
#  'hieroglyphics',
#  'was',
#  'a',
#  'figure',
#  'of',
#  'evident',
#  'pictorial',
#  'intent',
#  'though',
#  'its',
#  'impressionistic',
#  'execution',
#  'forbade',
#  'a',
#  'very',
#  'clear',
#  'idea',
#  'of',
#  'its',
#  'nature',
#  'it',
#  'seemed',
#  'to',
#  'be',
#  'a',
#  'sort',
#  'of',
#  'monster',
#  'or',
#  'symbol',
#  'representing',
#  'a',
#  'monster',
#  'of',
#  'a',
#  'form',
#  'which',
#  'only',
#  'a',
#  'diseased',
#  'fancy',
#  'could',
#  'conceive',
#  'if',
#  'i',
#  'say',
#  'that',
#  'my',
#  'somewhat',
#  'extravagant',
#  'imagination',
#  'yielded',
#  'simultaneous',
#  'pictures',
#  'of',
#  'an',
#  'octopus',
#  'a',
#  'dragon',
#  'and',
#  'a',
#  'human',
#  'caricature',
#  'i',
#  'shall',
#  'not',
#  'be',
#  'unfaithful',
#  'to',
#  'the',
#  'spirit',
#  'of',
#  'the',
#  'thing',
#  'a',
#  'pulpy',
#  'tentacled',
#  'head',
#  'surmounted',
#  'a',
#  'grotesque',
#  'and',
#  'scaly',
#  'body',
#  'with',
#  'rudimentary',
#  'wings',
#  'but',
#  'it',
#  'was',
#  'the',
#  'general',
#  'outline',
#  'of',
#  'the',
#  'whole',
#  'which',
#  'made',
#  'it',
#  'most',
#  'shockingly',
#  'frightful',
#  'behind',
#  'the',
#  'figure',
#  'was',
#  'a',
#  'vague',
#  'suggestions',
#  'of',
#  'a',
#  'cyclopean',
#  'architectural',
#  'background',
#  'the',
#  'writing',
#  'accompanying',
#  'this',
#  'oddity',
#  'was',
#  'aside',
#  'from',
#  'a',
#  'stack',
#  'of',
#  'press',
#  'cuttings',
#  'in',
#  'professor',
#  'angell',
#  "'s",
#  'most',
#  'recent',
#  'hand',
#  'and',
#  'made',
#  'no',
#  'pretense',
#  'to',
#  'literary',
#  'style',
#  'what',
#  'seemed',
#  'to',
#  'be',
#  'the',
#  'main',
#  'document',
#  'was',
#  'headed',
#  'cthulhu',
#  'cult',
#  'in',
#  'characters',
#  'painstakingly',
#  'printed',
#  'to',
#  'avoid',
#  'the',
#  ...]

# %% [markdown]
# 1.1 - Transformar las oraciones en secuencias (tokens) de palabras

# %%
# Recorrer todas las filas y transformar las oraciones
# en secuencias de palabras
sentence_tokens = []
for _, row in df[:None].iterrows():
    sentence_tokens.append(text_to_word_sequence(row[0]))

# %%
# Demos un vistazo
sentence_tokens[:2]
# Out:
# [["'the",
#   'call',
#   'of',
#   'cthulhu',
#   'by',
#   'h',
#   'p',
#   'lovecraft',
#   'the',
#   'call',
#   'of',
#   'cthulhu',
#   'of',
#   'such',
#   'great',
#   'powers',
#   'or',
#   'beings',
#   'there',
#   'may',
#   'be',
#   'conceivably',
#   'a',
#   'survival',
#   'a',
#   'survival',
#   'of',
#   'a',
#   'hugely',
#   'remote',
#   'period',
#   'when',
#   'consciousness',
#   'was',
#   'manifested',
#   'perhaps',
#   'in',
#   'shapes',
#   'and',
#   'forms',
#   'long',
#   'since',
#   'withdrawn',
#   'before',
#   'the',
#   'tide',
#   'of',
#   'advancing',
#   'humanity',
#   'forms',
#   'of',
#   'which',
#   'poetry',
#   'and',
#   'legend',
#   'alone',
#   'have',
#   'caught',
#   'a',
#   'flying',
#   'memory',
#   'and',
#   'called',
#   'them',
#   'gods',
#   'monsters',
#   'mythical',
#   'beings',
#   'of',
#   'all',
#   'sorts',
#   'and',
#   'kinds',
#   '—',
#   'algernon',
#   'blackwood',
#   'part',
#   'i',
#   'the',
#   'horror',
#   'in',
#   'clay',
#   'the',
#   'most',
#   'merciful',
#   'thing',
#   'in',
#   'the',
#   'world',
#   'i',
#   'think',
#   'is',
#   'the',
#   'inability',
#   'of',
#   'the',
#   'human',
#   'mind',
#   'to',
#   'correlate',
#   'all',
#   'its',
#   'contents',
#   'we',
#   'live',
#   'on',
#   'a',
#   'placid',
#   'island',
#   'of',
#   'ignorance',
#   'in',
#   'the',
#   'midst',
#   'of',
#   'black',
#   'seas',
#   'of',
#   'infinity',
#   'and',
#   'it',
#   'was',
#   'not',
#   'meant',
#   'that',
#   'we',
#   'should',
#   'voyage',
#   'far',
#   'the',
#   'sciences',
#   'each',
#   'straining',
#   'in',
#   'its',
#   'own',
#   'direction',
#   'have',
#   'hitherto',
#   'harmed',
#   'us',
#   'little',
#   'but',
#   'some',
#   'day',
#   'the',
#   'piecing',
#   'together',
#   'of',
#   'dissociated',
#   'knowledge',
#   'will',
#   'open',
#   'up',
#   'such',
#   'terrifying',
#   'vistas',
#   'of',
#   'reality',
#   'and',
#   'of',
#   'our',
#   'frightful',
#   'position',
#   'therein',
#   'that',
#   'we',
#   'shall',
#   'either',
#   'go',
#   'mad',
#   'from',
#   'the',
#   'revelation',
#   'or',
#   'flee',
#   'from',
#   'the',
#   'light',
#   'into',
#   'the',
#   'peace',
#   'and',
#   'safety',
#   'of',
#   'a',
#   'new',
#   'dark',
#   'age',
#   'theosophists',
#   'have',
#   'guessed',
#   'at',
#   'the',
#   'awesome',
#   'grandeur',
#   'of',
#   'the',
#   'cosmic',
#   'cycle',
#   'wherein',
#   'our',
#   'world',
#   'and',
#   'human',
#   'race',
#   'form',
#   'transient',
#   'incidents',
#   'they',
#   'have',
#   'hinted',
#   'at',
#   'strange',
#   'survivals',
#   'in',
#   'terms',
#   'which',
#   'would',
#   'freeze',
#   'the',
#   'blood',
#   'if',
#   'not',
#   'masked',
#   'by',
#   'a',
#   'bland',
#   'optimism',
#   'but',
#   'it',
#   'is',
#   'not',
#   'from',
#   'them',
#   'that',
#   'there',
#   'came',
#   'the',
#   'single',
#   'glimpse',
#   'of',
#   'forbidden',
#   'eons',
#   'which',
#   'chills',
#   'me',
#   'when',
#   'i',
#   'think',
#   'of',
#   'it',
#   'and',
#   'maddens',
#   'me',
#   'when',
#   'i',
#   'dream',
#   'of',
#   'it',
#   'that',
#   'glimpse',
#   'like',
#   'all',
#   'dread',
#   'glimpses',
#   'of',
#   'truth',
#   'flashed',
#   'out',
#   'from',
#   'an',
#   'accidental',
#   'piecing',
#   'together',
#   'of',
#   'separated',
#   'things—in',
#   'this',
#   'case',
#   'an',
#   'old',
#   'newspaper',
#   'item',
#   'and',
#   'the',
#   'notes',
#   'of',
#   'a',
#   'dead',
#   'professor',
#   'i',
#   'hope',
#   'that',
#   'no',
#   'one',
#   'else',
#   'will',
#   'accomplish',
#   'this',
#   'piecing',
#   'out',
#   'certainly',
#   'if',
#   'i',
#   'live',
#   'i',
#   'shall',
#   'never',
#   'knowingly',
#   'supply',
#   'a',
#   'link',
#   'in',
#   'so',
#   'hideous',
#   'a',
#   'chain',
#   'i',
#   'think',
#   'that',
#   'the',
#   'professor',
#   'too',
#   'intended',
#   'to',
#   'keep',
#   'silent',
#   'regarding',
#   'the',
#   'part',
#   'he',
#   'knew',
#   'and',
#   'that',
#   'he',
#   'would',
#   'have',
#   'destroyed',
#   'his',
#   'notes',
#   'had',
#   'not',
#   'sudden',
#   'death',
#   'seized',
#   'him',
#   'my',
#   'knowledge',
#   'of',
#   'the',
#   'thing',
#   'began',
#   'in',
#   'the',
#   'winter',
#   'of',
#   '1926',
#   '27',
#   'with',
#   'the',
#   'death',
#   'of',
#   'my',
#   'great',
#   'uncle',
#   'george',
#   'gammell',
#   'angell',
#   'professor',
#   'emeritus',
#   'of',
#   'semitic',
#   'languages',
#   'in',
#   'brown',
#   'university',
#   'providence',
#   'rhode',
#   'island',
#   'professor',
#   'angell',
#   'was',
#   'widely',
#   'known',
#   'as',
#   'an',
#   'authority',
#   'on',
#   'ancient',
#   'inscriptions',
#   'and',
#   'had',
#   'frequently',
#   'been',
#   'resorted',
#   'to',
#   'by',
#   'the',
#   'heads',
#   'of',
#   'prominent',
#   'museums',
#   'so',
#   'that',
#   'his',
#   'passing',
#   'at',
#   'the',
#   'age',
#   'of',
#   'ninety',
#   'two',
#   'may',
#   'be',
#   'recalled',
#   'by',
#   'many',
#   'locally',
#   'interest',
#   'was',
#   'intensified',
#   'by',
#   'the',
#   'obscurity',
#   'of',
#   'the',
#   'cause',
#   'of',
#   'death',
#   'the',
#   'professor',
#   'had',
#   'been',
#   'stricken',
#   'whilst',
#   'returning',
#   'from',
#   'the',
#   'newport',
#   'boat',
#   'falling',
#   'suddenly',
#   'as',
#   'witnesses',
#   'said',
#   'after',
#   'having',
#   'been',
#   'jostled',
#   'by',
#   'a',
#   'nautical',
#   'looking',
#   'negro',
#   'who',
#   'had',
#   'come',
#   'from',
#   'one',
#   'of',
#   'the',
#   'queer',
#   'dark',
#   'courts',
#   'on',
#   'the',
#   'precipitous',
#   'hillside',
#   'which',
#   'formed',
#   'a',
#   'short',
#   'cut',
#   'from',
#   'the',
#   'waterfront',
#   'to',
#   'the',
#   'deceased',
#   "'s",
#   'home',
#   'in',
#   'williams',
#   'street',
#   'physicians',
#   'were',
#   'unable',
#   'to',
#   'find',
#   'any',
#   'visible',
#   'disorder',
#   'but',
#   'concluded',
#   'after',
#   'perplexed',
#   'debate',
#   'that',
#   'some',
#   'obscure',
#   'lesion',
#   'of',
#   'the',
#   'heart',
#   'induced',
#   'by',
#   'the',
#   'brisk',
#   'ascent',
#   'of',
#   'so',
#   'steep',
#   'a',
#   'hill',
#   'by',
#   'so',
#   'elderly',
#   'a',
#   'man',
#   'was',
#   'responsible',
#   'for',
#   'the',
#   'end',
#   'at',
#   'the',
#   'time',
#   'i',
#   'saw',
#   'no',
#   'reason',
#   'to',
#   'dissent',
#   'from',
#   'this',
#   'dictum',
#   'but',
#   'latterly',
#   'i',
#   'am',
#   'inclined',
#   'to',
#   'wonder—and',
#   'more',
#   'than',
#   'wonder',
#   'as',
#   'my',
#   'great',
#   'uncle',
#   "'s",
#   'heir',
#   'and',
#   'executor',
#   'for',
#   'he',
#   'died',
#   'a',
#   'childless',
#   'widower',
#   'i',
#   'was',
#   'expected',
#   'to',
#   'go',
#   'over',
#   'his',
#   'papers',
#   'with',
#   'some',
#   'thoroughness',
#   'and',
#   'for',
#   'that',
#   'purpose',
#   'moved',
#   'his',
#   'entire',
#   'set',
#   'of',
#   'files',
#   'and',
#   'boxes',
#   'to',
#   'my',
#   'quarters',
#   'in',
#   'boston',
#   'much',
#   'of',
#   'the',
#   'material',
#   'which',
#   'i',
#   'correlated',
#   'will',
#   'be',
#   'later',
#   'published',
#   'by',
#   'the',
#   'american',
#   'archaeological',
#   'society',
#   'but',
#   'there',
#   'was',
#   'one',
#   'box',
#   'which',
#   'i',
#   'found',
#   'exceedingly',
#   'puzzling',
#   'and',
#   'which',
#   'i',
#   'felt',
#   'much',
#   'averse',
#   'from',
#   'showing',
#   'to',
#   'other',
#   'eyes',
#   'it',
#   'had',
#   'been',
#   'locked',
#   'and',
#   'i',
#   'did',
#   'not',
#   'find',
#   'the',
#   'key',
#   'till',
#   'it',
#   'occurred',
#   'to',
#   'me',
#   'to',
#   'examine',
#   'the',
#   'personal',
#   'ring',
#   'which',
#   'the',
#   'professor',
#   'carried',
#   'in',
#   'his',
#   'pocket',
#   'then',
#   'indeed',
#   'i',
#   'succeeded',
#   'in',
#   'opening',
#   'it',
#   'but',
#   'when',
#   'i',
#   'did',
#   'so',
#   'seemed',
#   'only',
#   'to',
#   'be',
#   'confronted',
#   'by',
#   'a',
#   'greater',
#   'and',
#   'more',
#   'closely',
#   'locked',
#   'barrier',
#   'for',
#   'what',
#   'could',
#   'be',
#   'the',
#   'meaning',
#   'of',
#   'the',
#   'queer',
#   'clay',
#   'bas',
#   'relief',
#   'and',
#   'the',
#   'disjointed',
#   'jottings',
#   'ramblings',
#   'and',
#   'cuttings',
#   'which',
#   'i',
#   'found',
#   'had',
#   'my',
#   'uncle',
#   'in',
#   'his',
#   'latter',
#   'years',
#   'become',
#   'credulous',
#   'of',
#   'the',
#   'most',
#   'superficial',
#   'impostures',
#   'i',
#   'resolved',
#   'to',
#   'search',
#   'out',
#   'the',
#   'eccentric',
#   'sculptor',
#   'responsible',
#   'for',
#   'this',
#   'apparent',
#   'disturbance',
#   'of',
#   'an',
#   'old',
#   'man',
#   "'s",
#   'peace',
#   'of',
#   'mind',
#   'the',
#   'bas',
#   'relief',
#   'was',
#   'a',
#   'rough',
#   'rectangle',
#   'less',
#   'than',
#   'an',
#   'inch',
#   'thick',
#   'and',
#   'about',
#   'five',
#   'by',
#   'six',
#   'inches',
#   'in',
#   'area',
#   'obviously',
#   'of',
#   'modern',
#   'origin',
#   'its',
#   'designs',
#   'however',
#   'were',
#   'far',
#   'from',
#   'modern',
#   'in',
#   'atmosphere',
#   'and',
#   'suggestion',
#   'for',
#   'although',
#   'the',
#   'vagaries',
#   'of',
#   'cubism',
#   'and',
#   'futurism',
#   'are',
#   'many',
#   'and',
#   'wild',
#   'they',
#   'do',
#   'not',
#   'often',
#   'reproduce',
#   'that',
#   'cryptic',
#   'regularity',
#   'which',
#   'lurks',
#   'in',
#   'prehistoric',
#   'writing',
#   'and',
#   'writing',
#   'of',
#   'some',
#   'kind',
#   'the',
#   'bulk',
#   'of',
#   'these',
#   'designs',
#   'seemed',
#   'certainly',
#   'to',
#   'be',
#   'though',
#   'my',
#   'memory',
#   'despite',
#   'much',
#   'the',
#   'papers',
#   'and',
#   'collections',
#   'of',
#   'my',
#   'uncle',
#   'failed',
#   'in',
#   'any',
#   'way',
#   'to',
#   'identify',
#   'this',
#   'particular',
#   'species',
#   'or',
#   'even',
#   'hint',
#   'at',
#   'its',
#   'remotest',
#   'affiliations',
#   'above',
#   'these',
#   'apparent',
#   'hieroglyphics',
#   'was',
#   'a',
#   'figure',
#   'of',
#   'evident',
#   'pictorial',
#   'intent',
#   'though',
#   'its',
#   'impressionistic',
#   'execution',
#   'forbade',
#   'a',
#   'very',
#   'clear',
#   'idea',
#   'of',
#   'its',
#   'nature',
#   'it',
#   'seemed',
#   'to',
#   'be',
#   'a',
#   'sort',
#   'of',
#   'monster',
#   'or',
#   'symbol',
#   'representing',
#   'a',
#   'monster',
#   'of',
#   'a',
#   'form',
#   'which',
#   'only',
#   'a',
#   'diseased',
#   'fancy',
#   'could',
#   'conceive',
#   'if',
#   'i',
#   'say',
#   'that',
#   'my',
#   'somewhat',
#   'extravagant',
#   'imagination',
#   'yielded',
#   'simultaneous',
#   'pictures',
#   'of',
#   'an',
#   'octopus',
#   'a',
#   'dragon',
#   'and',
#   'a',
#   'human',
#   'caricature',
#   'i',
#   'shall',
#   'not',
#   'be',
#   'unfaithful',
#   'to',
#   'the',
#   'spirit',
#   'of',
#   'the',
#   'thing',
#   'a',
#   'pulpy',
#   'tentacled',
#   'head',
#   'surmounted',
#   'a',
#   'grotesque',
#   'and',
#   'scaly',
#   'body',
#   'with',
#   'rudimentary',
#   'wings',
#   'but',
#   'it',
#   'was',
#   'the',
#   'general',
#   'outline',
#   'of',
#   'the',
#   'whole',
#   'which',
#   'made',
#   'it',
#   'most',
#   'shockingly',
#   'frightful',
#   'behind',
#   'the',
#   'figure',
#   'was',
#   'a',
#   'vague',
#   'suggestions',
#   'of',
#   'a',
#   'cyclopean',
#   'architectural',
#   'background',
#   'the',
#   'writing',
#   'accompanying',
#   'this',
#   'oddity',
#   'was',
#   'aside',
#   'from',
#   'a',
#   'stack',
#   'of',
#   'press',
#   'cuttings',
#   'in',
#   'professor',
#   'angell',
#   "'s",
#   'most',
#   'recent',
#   'hand',
#   'and',
#   'made',
#   'no',
#   'pretense',
#   'to',
#   'literary',
#   'style',
#   'what',
#   'seemed',
#   'to',
#   'be',
#   'the',
#   'main',
#   'document',
#   'was',
#   'headed',
#   'cthulhu',
#   'cult',
#   'in',
#   'characters',
#   'painstakingly',
#   'printed',
#   'to',
#   'avoid',
#   'the',
#   ...]]

# %%
# Código para hacer el desfazaje de las palabras
# según el train_len
text_sequences = []

for i in range(train_len, len(tokens)):
  seq = tokens[i-train_len:i]
  text_sequences.append(seq)

# %%
# Demos un vistazo a nuestros vectores para entrenar el modelo
text_sequences
# Out:
# [["'the", 'call', 'of', 'cthulhu'],
#  ['call', 'of', 'cthulhu', 'by'],
#  ['of', 'cthulhu', 'by', 'h'],
#  ['cthulhu', 'by', 'h', 'p'],
#  ['by', 'h', 'p', 'lovecraft'],
#  ['h', 'p', 'lovecraft', 'the'],
#  ['p', 'lovecraft', 'the', 'call'],
#  ['lovecraft', 'the', 'call', 'of'],
#  ['the', 'call', 'of', 'cthulhu'],
#  ['call', 'of', 'cthulhu', 'of'],
#  ['of', 'cthulhu', 'of', 'such'],
#  ['cthulhu', 'of', 'such', 'great'],
#  ['of', 'such', 'great', 'powers'],
#  ['such', 'great', 'powers', 'or'],
#  ['great', 'powers', 'or', 'beings'],
#  ['powers', 'or', 'beings', 'there'],
#  ['or', 'beings', 'there', 'may'],
#  ['beings', 'there', 'may', 'be'],
#  ['there', 'may', 'be', 'conceivably'],
#  ['may', 'be', 'conceivably', 'a'],
#  ['be', 'conceivably', 'a', 'survival'],
#  ['conceivably', 'a', 'survival', 'a'],
#  ['a', 'survival', 'a', 'survival'],
#  ['survival', 'a', 'survival', 'of'],
#  ['a', 'survival', 'of', 'a'],
#  ['survival', 'of', 'a', 'hugely'],
#  ['of', 'a', 'hugely', 'remote'],
#  ['a', 'hugely', 'remote', 'period'],
#  ['hugely', 'remote', 'period', 'when'],
#  ['remote', 'period', 'when', 'consciousness'],
#  ['period', 'when', 'consciousness', 'was'],
#  ['when', 'consciousness', 'was', 'manifested'],
#  ['consciousness', 'was', 'manifested', 'perhaps'],
#  ['was', 'manifested', 'perhaps', 'in'],
#  ['manifested', 'perhaps', 'in', 'shapes'],
#  ['perhaps', 'in', 'shapes', 'and'],
#  ['in', 'shapes', 'and', 'forms'],
#  ['shapes', 'and', 'forms', 'long'],
#  ['and', 'forms', 'long', 'since'],
#  ['forms', 'long', 'since', 'withdrawn'],
#  ['long', 'since', 'withdrawn', 'before'],
#  ['since', 'withdrawn', 'before', 'the'],
#  ['withdrawn', 'before', 'the', 'tide'],
#  ['before', 'the', 'tide', 'of'],
#  ['the', 'tide', 'of', 'advancing'],
#  ['tide', 'of', 'advancing', 'humanity'],
#  ['of', 'advancing', 'humanity', 'forms'],
#  ['advancing', 'humanity', 'forms', 'of'],
#  ['humanity', 'forms', 'of', 'which'],
#  ['forms', 'of', 'which', 'poetry'],
#  ['of', 'which', 'poetry', 'and'],
#  ['which', 'poetry', 'and', 'legend'],
#  ['poetry', 'and', 'legend', 'alone'],
#  ['and', 'legend', 'alone', 'have'],
#  ['legend', 'alone', 'have', 'caught'],
#  ['alone', 'have', 'caught', 'a'],
#  ['have', 'caught', 'a', 'flying'],
#  ['caught', 'a', 'flying', 'memory'],
#  ['a', 'flying', 'memory', 'and'],
#  ['flying', 'memory', 'and', 'called'],
#  ['memory', 'and', 'called', 'them'],
#  ['and', 'called', 'them', 'gods'],
#  ['called', 'them', 'gods', 'monsters'],
#  ['them', 'gods', 'monsters', 'mythical'],
#  ['gods', 'monsters', 'mythical', 'beings'],
#  ['monsters', 'mythical', 'beings', 'of'],
#  ['mythical', 'beings', 'of', 'all'],
#  ['beings', 'of', 'all', 'sorts'],
#  ['of', 'all', 'sorts', 'and'],
#  ['all', 'sorts', 'and', 'kinds'],
#  ['sorts', 'and', 'kinds', '—'],
#  ['and', 'kinds', '—', 'algernon'],
#  ['kinds', '—', 'algernon', 'blackwood'],
#  ['—', 'algernon', 'blackwood', 'part'],
#  ['algernon', 'blackwood', 'part', 'i'],
#  ['blackwood', 'part', 'i', 'the'],
#  ['part', 'i', 'the', 'horror'],
#  ['i', 'the', 'horror', 'in'],
#  ['the', 'horror', 'in', 'clay'],
#  ['horror', 'in', 'clay', 'the'],
#  ['in', 'clay', 'the', 'most'],
#  ['clay', 'the', 'most', 'merciful'],
#  ['the', 'most', 'merciful', 'thing'],
#  ['most', 'merciful', 'thing', 'in'],
#  ['merciful', 'thing', 'in', 'the'],
#  ['thing', 'in', 'the', 'world'],
#  ['in', 'the', 'world', 'i'],
#  ['the', 'world', 'i', 'think'],
#  ['world', 'i', 'think', 'is'],
#  ['i', 'think', 'is', 'the'],
#  ['think', 'is', 'the', 'inability'],
#  ['is', 'the', 'inability', 'of'],
#  ['the', 'inability', 'of', 'the'],
#  ['inability', 'of', 'the', 'human'],
#  ['of', 'the', 'human', 'mind'],
#  ['the', 'human', 'mind', 'to'],
#  ['human', 'mind', 'to', 'correlate'],
#  ['mind', 'to', 'correlate', 'all'],
#  ['to', 'correlate', 'all', 'its'],
#  ['correlate', 'all', 'its', 'contents'],
#  ['all', 'its', 'contents', 'we'],
#  ['its', 'contents', 'we', 'live'],
#  ['contents', 'we', 'live', 'on'],
#  ['we', 'live', 'on', 'a'],
#  ['live', 'on', 'a', 'placid'],
#  ['on', 'a', 'placid', 'island'],
#  ['a', 'placid', 'island', 'of'],
#  ['placid', 'island', 'of', 'ignorance'],
#  ['island', 'of', 'ignorance', 'in'],
#  ['of', 'ignorance', 'in', 'the'],
#  ['ignorance', 'in', 'the', 'midst'],
#  ['in', 'the', 'midst', 'of'],
#  ['the', 'midst', 'of', 'black'],
#  ['midst', 'of', 'black', 'seas'],
#  ['of', 'black', 'seas', 'of'],
#  ['black', 'seas', 'of', 'infinity'],
#  ['seas', 'of', 'infinity', 'and'],
#  ['of', 'infinity', 'and', 'it'],
#  ['infinity', 'and', 'it', 'was'],
#  ['and', 'it', 'was', 'not'],
#  ['it', 'was', 'not', 'meant'],
#  ['was', 'not', 'meant', 'that'],
#  ['not', 'meant', 'that', 'we'],
#  ['meant', 'that', 'we', 'should'],
#  ['that', 'we', 'should', 'voyage'],
#  ['we', 'should', 'voyage', 'far'],
#  ['should', 'voyage', 'far', 'the'],
#  ['voyage', 'far', 'the', 'sciences'],
#  ['far', 'the', 'sciences', 'each'],
#  ['the', 'sciences', 'each', 'straining'],
#  ['sciences', 'each', 'straining', 'in'],
#  ['each', 'straining', 'in', 'its'],
#  ['straining', 'in', 'its', 'own'],
#  ['in', 'its', 'own', 'direction'],
#  ['its', 'own', 'direction', 'have'],
#  ['own', 'direction', 'have', 'hitherto'],
#  ['direction', 'have', 'hitherto', 'harmed'],
#  ['have', 'hitherto', 'harmed', 'us'],
#  ['hitherto', 'harmed', 'us', 'little'],
#  ['harmed', 'us', 'little', 'but'],
#  ['us', 'little', 'but', 'some'],
#  ['little', 'but', 'some', 'day'],
#  ['but', 'some', 'day', 'the'],
#  ['some', 'day', 'the', 'piecing'],
#  ['day', 'the', 'piecing', 'together'],
#  ['the', 'piecing', 'together', 'of'],
#  ['piecing', 'together', 'of', 'dissociated'],
#  ['together', 'of', 'dissociated', 'knowledge'],
#  ['of', 'dissociated', 'knowledge', 'will'],
#  ['dissociated', 'knowledge', 'will', 'open'],
#  ['knowledge', 'will', 'open', 'up'],
#  ['will', 'open', 'up', 'such'],
#  ['open', 'up', 'such', 'terrifying'],
#  ['up', 'such', 'terrifying', 'vistas'],
#  ['such', 'terrifying', 'vistas', 'of'],
#  ['terrifying', 'vistas', 'of', 'reality'],
#  ['vistas', 'of', 'reality', 'and'],
#  ['of', 'reality', 'and', 'of'],
#  ['reality', 'and', 'of', 'our'],
#  ['and', 'of', 'our', 'frightful'],
#  ['of', 'our', 'frightful', 'position'],
#  ['our', 'frightful', 'position', 'therein'],
#  ['frightful', 'position', 'therein', 'that'],
#  ['position', 'therein', 'that', 'we'],
#  ['therein', 'that', 'we', 'shall'],
#  ['that', 'we', 'shall', 'either'],
#  ['we', 'shall', 'either', 'go'],
#  ['shall', 'either', 'go', 'mad'],
#  ['either', 'go', 'mad', 'from'],
#  ['go', 'mad', 'from', 'the'],
#  ['mad', 'from', 'the', 'revelation'],
#  ['from', 'the', 'revelation', 'or'],
#  ['the', 'revelation', 'or', 'flee'],
#  ['revelation', 'or', 'flee', 'from'],
#  ['or', 'flee', 'from', 'the'],
#  ['flee', 'from', 'the', 'light'],
#  ['from', 'the', 'light', 'into'],
#  ['the', 'light', 'into', 'the'],
#  ['light', 'into', 'the', 'peace'],
#  ['into', 'the', 'peace', 'and'],
#  ['the', 'peace', 'and', 'safety'],
#  ['peace', 'and', 'safety', 'of'],
#  ['and', 'safety', 'of', 'a'],
#  ['safety', 'of', 'a', 'new'],
#  ['of', 'a', 'new', 'dark'],
#  ['a', 'new', 'dark', 'age'],
#  ['new', 'dark', 'age', 'theosophists'],
#  ['dark', 'age', 'theosophists', 'have'],
#  ['age', 'theosophists', 'have', 'guessed'],
#  ['theosophists', 'have', 'guessed', 'at'],
#  ['have', 'guessed', 'at', 'the'],
#  ['guessed', 'at', 'the', 'awesome'],
#  ['at', 'the', 'awesome', 'grandeur'],
#  ['the', 'awesome', 'grandeur', 'of'],
#  ['awesome', 'grandeur', 'of', 'the'],
#  ['grandeur', 'of', 'the', 'cosmic'],
#  ['of', 'the', 'cosmic', 'cycle'],
#  ['the', 'cosmic', 'cycle', 'wherein'],
#  ['cosmic', 'cycle', 'wherein', 'our'],
#  ['cycle', 'wherein', 'our', 'world'],
#  ['wherein', 'our', 'world', 'and'],
#  ['our', 'world', 'and', 'human'],
#  ['world', 'and', 'human', 'race'],
#  ['and', 'human', 'race', 'form'],
#  ['human', 'race', 'form', 'transient'],
#  ['race', 'form', 'transient', 'incidents'],
#  ['form', 'transient', 'incidents', 'they'],
#  ['transient', 'incidents', 'they', 'have'],
#  ['incidents', 'they', 'have', 'hinted'],
#  ['they', 'have', 'hinted', 'at'],
#  ['have', 'hinted', 'at', 'strange'],
#  ['hinted', 'at', 'strange', 'survivals'],
#  ['at', 'strange', 'survivals', 'in'],
#  ['strange', 'survivals', 'in', 'terms'],
#  ['survivals', 'in', 'terms', 'which'],
#  ['in', 'terms', 'which', 'would'],
#  ['terms', 'which', 'would', 'freeze'],
#  ['which', 'would', 'freeze', 'the'],
#  ['would', 'freeze', 'the', 'blood'],
#  ['freeze', 'the', 'blood', 'if'],
#  ['the', 'blood', 'if', 'not'],
#  ['blood', 'if', 'not', 'masked'],
#  ['if', 'not', 'masked', 'by'],
#  ['not', 'masked', 'by', 'a'],
#  ['masked', 'by', 'a', 'bland'],
#  ['by', 'a', 'bland', 'optimism'],
#  ['a', 'bland', 'optimism', 'but'],
#  ['bland', 'optimism', 'but', 'it'],
#  ['optimism', 'but', 'it', 'is'],
#  ['but', 'it', 'is', 'not'],
#  ['it', 'is', 'not', 'from'],
#  ['is', 'not', 'from', 'them'],
#  ['not', 'from', 'them', 'that'],
#  ['from', 'them', 'that', 'there'],
#  ['them', 'that', 'there', 'came'],
#  ['that', 'there', 'came', 'the'],
#  ['there', 'came', 'the', 'single'],
#  ['came', 'the', 'single', 'glimpse'],
#  ['the', 'single', 'glimpse', 'of'],
#  ['single', 'glimpse', 'of', 'forbidden'],
#  ['glimpse', 'of', 'forbidden', 'eons'],
#  ['of', 'forbidden', 'eons', 'which'],
#  ['forbidden', 'eons', 'which', 'chills'],
#  ['eons', 'which', 'chills', 'me'],
#  ['which', 'chills', 'me', 'when'],
#  ['chills', 'me', 'when', 'i'],
#  ['me', 'when', 'i', 'think'],
#  ['when', 'i', 'think', 'of'],
#  ['i', 'think', 'of', 'it'],
#  ['think', 'of', 'it', 'and'],
#  ['of', 'it', 'and', 'maddens'],
#  ['it', 'and', 'maddens', 'me'],
#  ['and', 'maddens', 'me', 'when'],
#  ['maddens', 'me', 'when', 'i'],
#  ['me', 'when', 'i', 'dream'],
#  ['when', 'i', 'dream', 'of'],
#  ['i', 'dream', 'of', 'it'],
#  ['dream', 'of', 'it', 'that'],
#  ['of', 'it', 'that', 'glimpse'],
#  ['it', 'that', 'glimpse', 'like'],
#  ['that', 'glimpse', 'like', 'all'],
#  ['glimpse', 'like', 'all', 'dread'],
#  ['like', 'all', 'dread', 'glimpses'],
#  ['all', 'dread', 'glimpses', 'of'],
#  ['dread', 'glimpses', 'of', 'truth'],
#  ['glimpses', 'of', 'truth', 'flashed'],
#  ['of', 'truth', 'flashed', 'out'],
#  ['truth', 'flashed', 'out', 'from'],
#  ['flashed', 'out', 'from', 'an'],
#  ['out', 'from', 'an', 'accidental'],
#  ['from', 'an', 'accidental', 'piecing'],
#  ['an', 'accidental', 'piecing', 'together'],
#  ['accidental', 'piecing', 'together', 'of'],
#  ['piecing', 'together', 'of', 'separated'],
#  ['together', 'of', 'separated', 'things—in'],
#  ['of', 'separated', 'things—in', 'this'],
#  ['separated', 'things—in', 'this', 'case'],
#  ['things—in', 'this', 'case', 'an'],
#  ['this', 'case', 'an', 'old'],
#  ['case', 'an', 'old', 'newspaper'],
#  ['an', 'old', 'newspaper', 'item'],
#  ['old', 'newspaper', 'item', 'and'],
#  ['newspaper', 'item', 'and', 'the'],
#  ['item', 'and', 'the', 'notes'],
#  ['and', 'the', 'notes', 'of'],
#  ['the', 'notes', 'of', 'a'],
#  ['notes', 'of', 'a', 'dead'],
#  ['of', 'a', 'dead', 'professor'],
#  ['a', 'dead', 'professor', 'i'],
#  ['dead', 'professor', 'i', 'hope'],
#  ['professor', 'i', 'hope', 'that'],
#  ['i', 'hope', 'that', 'no'],
#  ['hope', 'that', 'no', 'one'],
#  ['that', 'no', 'one', 'else'],
#  ['no', 'one', 'else', 'will'],
#  ['one', 'else', 'will', 'accomplish'],
#  ['else', 'will', 'accomplish', 'this'],
#  ['will', 'accomplish', 'this', 'piecing'],
#  ['accomplish', 'this', 'piecing', 'out'],
#  ['this', 'piecing', 'out', 'certainly'],
#  ['piecing', 'out', 'certainly', 'if'],
#  ['out', 'certainly', 'if', 'i'],
#  ['certainly', 'if', 'i', 'live'],
#  ['if', 'i', 'live', 'i'],
#  ['i', 'live', 'i', 'shall'],
#  ['live', 'i', 'shall', 'never'],
#  ['i', 'shall', 'never', 'knowingly'],
#  ['shall', 'never', 'knowingly', 'supply'],
#  ['never', 'knowingly', 'supply', 'a'],
#  ['knowingly', 'supply', 'a', 'link'],
#  ['supply', 'a', 'link', 'in'],
#  ['a', 'link', 'in', 'so'],
#  ['link', 'in', 'so', 'hideous'],
#  ['in', 'so', 'hideous', 'a'],
#  ['so', 'hideous', 'a', 'chain'],
#  ['hideous', 'a', 'chain', 'i'],
#  ['a', 'chain', 'i', 'think'],
#  ['chain', 'i', 'think', 'that'],
#  ['i', 'think', 'that', 'the'],
#  ['think', 'that', 'the', 'professor'],
#  ['that', 'the', 'professor', 'too'],
#  ['the', 'professor', 'too', 'intended'],
#  ['professor', 'too', 'intended', 'to'],
#  ['too', 'intended', 'to', 'keep'],
#  ['intended', 'to', 'keep', 'silent'],
#  ['to', 'keep', 'silent', 'regarding'],
#  ['keep', 'silent', 'regarding', 'the'],
#  ['silent', 'regarding', 'the', 'part'],
#  ['regarding', 'the', 'part', 'he'],
#  ['the', 'part', 'he', 'knew'],
#  ['part', 'he', 'knew', 'and'],
#  ['he', 'knew', 'and', 'that'],
#  ['knew', 'and', 'that', 'he'],
#  ['and', 'that', 'he', 'would'],
#  ['that', 'he', 'would', 'have'],
#  ['he', 'would', 'have', 'destroyed'],
#  ['would', 'have', 'destroyed', 'his'],
#  ['have', 'destroyed', 'his', 'notes'],
#  ['destroyed', 'his', 'notes', 'had'],
#  ['his', 'notes', 'had', 'not'],
#  ['notes', 'had', 'not', 'sudden'],
#  ['had', 'not', 'sudden', 'death'],
#  ['not', 'sudden', 'death', 'seized'],
#  ['sudden', 'death', 'seized', 'him'],
#  ['death', 'seized', 'him', 'my'],
#  ['seized', 'him', 'my', 'knowledge'],
#  ['him', 'my', 'knowledge', 'of'],
#  ['my', 'knowledge', 'of', 'the'],
#  ['knowledge', 'of', 'the', 'thing'],
#  ['of', 'the', 'thing', 'began'],
#  ['the', 'thing', 'began', 'in'],
#  ['thing', 'began', 'in', 'the'],
#  ['began', 'in', 'the', 'winter'],
#  ['in', 'the', 'winter', 'of'],
#  ['the', 'winter', 'of', '1926'],
#  ['winter', 'of', '1926', '27'],
#  ['of', '1926', '27', 'with'],
#  ['1926', '27', 'with', 'the'],
#  ['27', 'with', 'the', 'death'],
#  ['with', 'the', 'death', 'of'],
#  ['the', 'death', 'of', 'my'],
#  ['death', 'of', 'my', 'great'],
#  ['of', 'my', 'great', 'uncle'],
#  ['my', 'great', 'uncle', 'george'],
#  ['great', 'uncle', 'george', 'gammell'],
#  ['uncle', 'george', 'gammell', 'angell'],
#  ['george', 'gammell', 'angell', 'professor'],
#  ['gammell', 'angell', 'professor', 'emeritus'],
#  ['angell', 'professor', 'emeritus', 'of'],
#  ['professor', 'emeritus', 'of', 'semitic'],
#  ['emeritus', 'of', 'semitic', 'languages'],
#  ['of', 'semitic', 'languages', 'in'],
#  ['semitic', 'languages', 'in', 'brown'],
#  ['languages', 'in', 'brown', 'university'],
#  ['in', 'brown', 'university', 'providence'],
#  ['brown', 'university', 'providence', 'rhode'],
#  ['university', 'providence', 'rhode', 'island'],
#  ['providence', 'rhode', 'island', 'professor'],
#  ['rhode', 'island', 'professor', 'angell'],
#  ['island', 'professor', 'angell', 'was'],
#  ['professor', 'angell', 'was', 'widely'],
#  ['angell', 'was', 'widely', 'known'],
#  ['was', 'widely', 'known', 'as'],
#  ['widely', 'known', 'as', 'an'],
#  ['known', 'as', 'an', 'authority'],
#  ['as', 'an', 'authority', 'on'],
#  ['an', 'authority', 'on', 'ancient'],
#  ['authority', 'on', 'ancient', 'inscriptions'],
#  ['on', 'ancient', 'inscriptions', 'and'],
#  ['ancient', 'inscriptions', 'and', 'had'],
#  ['inscriptions', 'and', 'had', 'frequently'],
#  ['and', 'had', 'frequently', 'been'],
#  ['had', 'frequently', 'been', 'resorted'],
#  ['frequently', 'been', 'resorted', 'to'],
#  ['been', 'resorted', 'to', 'by'],
#  ['resorted', 'to', 'by', 'the'],
#  ['to', 'by', 'the', 'heads'],
#  ['by', 'the', 'heads', 'of'],
#  ['the', 'heads', 'of', 'prominent'],
#  ['heads', 'of', 'prominent', 'museums'],
#  ['of', 'prominent', 'museums', 'so'],
#  ['prominent', 'museums', 'so', 'that'],
#  ['museums', 'so', 'that', 'his'],
#  ['so', 'that', 'his', 'passing'],
#  ['that', 'his', 'passing', 'at'],
#  ['his', 'passing', 'at', 'the'],
#  ['passing', 'at', 'the', 'age'],
#  ['at', 'the', 'age', 'of'],
#  ['the', 'age', 'of', 'ninety'],
#  ['age', 'of', 'ninety', 'two'],
#  ['of', 'ninety', 'two', 'may'],
#  ['ninety', 'two', 'may', 'be'],
#  ['two', 'may', 'be', 'recalled'],
#  ['may', 'be', 'recalled', 'by'],
#  ['be', 'recalled', 'by', 'many'],
#  ['recalled', 'by', 'many', 'locally'],
#  ['by', 'many', 'locally', 'interest'],
#  ['many', 'locally', 'interest', 'was'],
#  ['locally', 'interest', 'was', 'intensified'],
#  ['interest', 'was', 'intensified', 'by'],
#  ['was', 'intensified', 'by', 'the'],
#  ['intensified', 'by', 'the', 'obscurity'],
#  ['by', 'the', 'obscurity', 'of'],
#  ['the', 'obscurity', 'of', 'the'],
#  ['obscurity', 'of', 'the', 'cause'],
#  ['of', 'the', 'cause', 'of'],
#  ['the', 'cause', 'of', 'death'],
#  ['cause', 'of', 'death', 'the'],
#  ['of', 'death', 'the', 'professor'],
#  ['death', 'the', 'professor', 'had'],
#  ['the', 'professor', 'had', 'been'],
#  ['professor', 'had', 'been', 'stricken'],
#  ['had', 'been', 'stricken', 'whilst'],
#  ['been', 'stricken', 'whilst', 'returning'],
#  ['stricken', 'whilst', 'returning', 'from'],
#  ['whilst', 'returning', 'from', 'the'],
#  ['returning', 'from', 'the', 'newport'],
#  ['from', 'the', 'newport', 'boat'],
#  ['the', 'newport', 'boat', 'falling'],
#  ['newport', 'boat', 'falling', 'suddenly'],
#  ['boat', 'falling', 'suddenly', 'as'],
#  ['falling', 'suddenly', 'as', 'witnesses'],
#  ['suddenly', 'as', 'witnesses', 'said'],
#  ['as', 'witnesses', 'said', 'after'],
#  ['witnesses', 'said', 'after', 'having'],
#  ['said', 'after', 'having', 'been'],
#  ['after', 'having', 'been', 'jostled'],
#  ['having', 'been', 'jostled', 'by'],
#  ['been', 'jostled', 'by', 'a'],
#  ['jostled', 'by', 'a', 'nautical'],
#  ['by', 'a', 'nautical', 'looking'],
#  ['a', 'nautical', 'looking', 'negro'],
#  ['nautical', 'looking', 'negro', 'who'],
#  ['looking', 'negro', 'who', 'had'],
#  ['negro', 'who', 'had', 'come'],
#  ['who', 'had', 'come', 'from'],
#  ['had', 'come', 'from', 'one'],
#  ['come', 'from', 'one', 'of'],
#  ['from', 'one', 'of', 'the'],
#  ['one', 'of', 'the', 'queer'],
#  ['of', 'the', 'queer', 'dark'],
#  ['the', 'queer', 'dark', 'courts'],
#  ['queer', 'dark', 'courts', 'on'],
#  ['dark', 'courts', 'on', 'the'],
#  ['courts', 'on', 'the', 'precipitous'],
#  ['on', 'the', 'precipitous', 'hillside'],
#  ['the', 'precipitous', 'hillside', 'which'],
#  ['precipitous', 'hillside', 'which', 'formed'],
#  ['hillside', 'which', 'formed', 'a'],
#  ['which', 'formed', 'a', 'short'],
#  ['formed', 'a', 'short', 'cut'],
#  ['a', 'short', 'cut', 'from'],
#  ['short', 'cut', 'from', 'the'],
#  ['cut', 'from', 'the', 'waterfront'],
#  ['from', 'the', 'waterfront', 'to'],
#  ['the', 'waterfront', 'to', 'the'],
#  ['waterfront', 'to', 'the', 'deceased'],
#  ['to', 'the', 'deceased', "'s"],
#  ['the', 'deceased', "'s", 'home'],
#  ['deceased', "'s", 'home', 'in'],
#  ["'s", 'home', 'in', 'williams'],
#  ['home', 'in', 'williams', 'street'],
#  ['in', 'williams', 'street', 'physicians'],
#  ['williams', 'street', 'physicians', 'were'],
#  ['street', 'physicians', 'were', 'unable'],
#  ['physicians', 'were', 'unable', 'to'],
#  ['were', 'unable', 'to', 'find'],
#  ['unable', 'to', 'find', 'any'],
#  ['to', 'find', 'any', 'visible'],
#  ['find', 'any', 'visible', 'disorder'],
#  ['any', 'visible', 'disorder', 'but'],
#  ['visible', 'disorder', 'but', 'concluded'],
#  ['disorder', 'but', 'concluded', 'after'],
#  ['but', 'concluded', 'after', 'perplexed'],
#  ['concluded', 'after', 'perplexed', 'debate'],
#  ['after', 'perplexed', 'debate', 'that'],
#  ['perplexed', 'debate', 'that', 'some'],
#  ['debate', 'that', 'some', 'obscure'],
#  ['that', 'some', 'obscure', 'lesion'],
#  ['some', 'obscure', 'lesion', 'of'],
#  ['obscure', 'lesion', 'of', 'the'],
#  ['lesion', 'of', 'the', 'heart'],
#  ['of', 'the', 'heart', 'induced'],
#  ['the', 'heart', 'induced', 'by'],
#  ['heart', 'induced', 'by', 'the'],
#  ['induced', 'by', 'the', 'brisk'],
#  ['by', 'the', 'brisk', 'ascent'],
#  ['the', 'brisk', 'ascent', 'of'],
#  ['brisk', 'ascent', 'of', 'so'],
#  ['ascent', 'of', 'so', 'steep'],
#  ['of', 'so', 'steep', 'a'],
#  ['so', 'steep', 'a', 'hill'],
#  ['steep', 'a', 'hill', 'by'],
#  ['a', 'hill', 'by', 'so'],
#  ['hill', 'by', 'so', 'elderly'],
#  ['by', 'so', 'elderly', 'a'],
#  ['so', 'elderly', 'a', 'man'],
#  ['elderly', 'a', 'man', 'was'],
#  ['a', 'man', 'was', 'responsible'],
#  ['man', 'was', 'responsible', 'for'],
#  ['was', 'responsible', 'for', 'the'],
#  ['responsible', 'for', 'the', 'end'],
#  ['for', 'the', 'end', 'at'],
#  ['the', 'end', 'at', 'the'],
#  ['end', 'at', 'the', 'time'],
#  ['at', 'the', 'time', 'i'],
#  ['the', 'time', 'i', 'saw'],
#  ['time', 'i', 'saw', 'no'],
#  ['i', 'saw', 'no', 'reason'],
#  ['saw', 'no', 'reason', 'to'],
#  ['no', 'reason', 'to', 'dissent'],
#  ['reason', 'to', 'dissent', 'from'],
#  ['to', 'dissent', 'from', 'this'],
#  ['dissent', 'from', 'this', 'dictum'],
#  ['from', 'this', 'dictum', 'but'],
#  ['this', 'dictum', 'but', 'latterly'],
#  ['dictum', 'but', 'latterly', 'i'],
#  ['but', 'latterly', 'i', 'am'],
#  ['latterly', 'i', 'am', 'inclined'],
#  ['i', 'am', 'inclined', 'to'],
#  ['am', 'inclined', 'to', 'wonder—and'],
#  ['inclined', 'to', 'wonder—and', 'more'],
#  ['to', 'wonder—and', 'more', 'than'],
#  ['wonder—and', 'more', 'than', 'wonder'],
#  ['more', 'than', 'wonder', 'as'],
#  ['than', 'wonder', 'as', 'my'],
#  ['wonder', 'as', 'my', 'great'],
#  ['as', 'my', 'great', 'uncle'],
#  ['my', 'great', 'uncle', "'s"],
#  ['great', 'uncle', "'s", 'heir'],
#  ['uncle', "'s", 'heir', 'and'],
#  ["'s", 'heir', 'and', 'executor'],
#  ['heir', 'and', 'executor', 'for'],
#  ['and', 'executor', 'for', 'he'],
#  ['executor', 'for', 'he', 'died'],
#  ['for', 'he', 'died', 'a'],
#  ['he', 'died', 'a', 'childless'],
#  ['died', 'a', 'childless', 'widower'],
#  ['a', 'childless', 'widower', 'i'],
#  ['childless', 'widower', 'i', 'was'],
#  ['widower', 'i', 'was', 'expected'],
#  ['i', 'was', 'expected', 'to'],
#  ['was', 'expected', 'to', 'go'],
#  ['expected', 'to', 'go', 'over'],
#  ['to', 'go', 'over', 'his'],
#  ['go', 'over', 'his', 'papers'],
#  ['over', 'his', 'papers', 'with'],
#  ['his', 'papers', 'with', 'some'],
#  ['papers', 'with', 'some', 'thoroughness'],
#  ['with', 'some', 'thoroughness', 'and'],
#  ['some', 'thoroughness', 'and', 'for'],
#  ['thoroughness', 'and', 'for', 'that'],
#  ['and', 'for', 'that', 'purpose'],
#  ['for', 'that', 'purpose', 'moved'],
#  ['that', 'purpose', 'moved', 'his'],
#  ['purpose', 'moved', 'his', 'entire'],
#  ['moved', 'his', 'entire', 'set'],
#  ['his', 'entire', 'set', 'of'],
#  ['entire', 'set', 'of', 'files'],
#  ['set', 'of', 'files', 'and'],
#  ['of', 'files', 'and', 'boxes'],
#  ['files', 'and', 'boxes', 'to'],
#  ['and', 'boxes', 'to', 'my'],
#  ['boxes', 'to', 'my', 'quarters'],
#  ['to', 'my', 'quarters', 'in'],
#  ['my', 'quarters', 'in', 'boston'],
#  ['quarters', 'in', 'boston', 'much'],
#  ['in', 'boston', 'much', 'of'],
#  ['boston', 'much', 'of', 'the'],
#  ['much', 'of', 'the', 'material'],
#  ['of', 'the', 'material', 'which'],
#  ['the', 'material', 'which', 'i'],
#  ['material', 'which', 'i', 'correlated'],
#  ['which', 'i', 'correlated', 'will'],
#  ['i', 'correlated', 'will', 'be'],
#  ['correlated', 'will', 'be', 'later'],
#  ['will', 'be', 'later', 'published'],
#  ['be', 'later', 'published', 'by'],
#  ['later', 'published', 'by', 'the'],
#  ['published', 'by', 'the', 'american'],
#  ['by', 'the', 'american', 'archaeological'],
#  ['the', 'american', 'archaeological', 'society'],
#  ['american', 'archaeological', 'society', 'but'],
#  ['archaeological', 'society', 'but', 'there'],
#  ['society', 'but', 'there', 'was'],
#  ['but', 'there', 'was', 'one'],
#  ['there', 'was', 'one', 'box'],
#  ['was', 'one', 'box', 'which'],
#  ['one', 'box', 'which', 'i'],
#  ['box', 'which', 'i', 'found'],
#  ['which', 'i', 'found', 'exceedingly'],
#  ['i', 'found', 'exceedingly', 'puzzling'],
#  ['found', 'exceedingly', 'puzzling', 'and'],
#  ['exceedingly', 'puzzling', 'and', 'which'],
#  ['puzzling', 'and', 'which', 'i'],
#  ['and', 'which', 'i', 'felt'],
#  ['which', 'i', 'felt', 'much'],
#  ['i', 'felt', 'much', 'averse'],
#  ['felt', 'much', 'averse', 'from'],
#  ['much', 'averse', 'from', 'showing'],
#  ['averse', 'from', 'showing', 'to'],
#  ['from', 'showing', 'to', 'other'],
#  ['showing', 'to', 'other', 'eyes'],
#  ['to', 'other', 'eyes', 'it'],
#  ['other', 'eyes', 'it', 'had'],
#  ['eyes', 'it', 'had', 'been'],
#  ['it', 'had', 'been', 'locked'],
#  ['had', 'been', 'locked', 'and'],
#  ['been', 'locked', 'and', 'i'],
#  ['locked', 'and', 'i', 'did'],
#  ['and', 'i', 'did', 'not'],
#  ['i', 'did', 'not', 'find'],
#  ['did', 'not', 'find', 'the'],
#  ['not', 'find', 'the', 'key'],
#  ['find', 'the', 'key', 'till'],
#  ['the', 'key', 'till', 'it'],
#  ['key', 'till', 'it', 'occurred'],
#  ['till', 'it', 'occurred', 'to'],
#  ['it', 'occurred', 'to', 'me'],
#  ['occurred', 'to', 'me', 'to'],
#  ['to', 'me', 'to', 'examine'],
#  ['me', 'to', 'examine', 'the'],
#  ['to', 'examine', 'the', 'personal'],
#  ['examine', 'the', 'personal', 'ring'],
#  ['the', 'personal', 'ring', 'which'],
#  ['personal', 'ring', 'which', 'the'],
#  ['ring', 'which', 'the', 'professor'],
#  ['which', 'the', 'professor', 'carried'],
#  ['the', 'professor', 'carried', 'in'],
#  ['professor', 'carried', 'in', 'his'],
#  ['carried', 'in', 'his', 'pocket'],
#  ['in', 'his', 'pocket', 'then'],
#  ['his', 'pocket', 'then', 'indeed'],
#  ['pocket', 'then', 'indeed', 'i'],
#  ['then', 'indeed', 'i', 'succeeded'],
#  ['indeed', 'i', 'succeeded', 'in'],
#  ['i', 'succeeded', 'in', 'opening'],
#  ['succeeded', 'in', 'opening', 'it'],
#  ['in', 'opening', 'it', 'but'],
#  ['opening', 'it', 'but', 'when'],
#  ['it', 'but', 'when', 'i'],
#  ['but', 'when', 'i', 'did'],
#  ['when', 'i', 'did', 'so'],
#  ['i', 'did', 'so', 'seemed'],
#  ['did', 'so', 'seemed', 'only'],
#  ['so', 'seemed', 'only', 'to'],
#  ['seemed', 'only', 'to', 'be'],
#  ['only', 'to', 'be', 'confronted'],
#  ['to', 'be', 'confronted', 'by'],
#  ['be', 'confronted', 'by', 'a'],
#  ['confronted', 'by', 'a', 'greater'],
#  ['by', 'a', 'greater', 'and'],
#  ['a', 'greater', 'and', 'more'],
#  ['greater', 'and', 'more', 'closely'],
#  ['and', 'more', 'closely', 'locked'],
#  ['more', 'closely', 'locked', 'barrier'],
#  ['closely', 'locked', 'barrier', 'for'],
#  ['locked', 'barrier', 'for', 'what'],
#  ['barrier', 'for', 'what', 'could'],
#  ['for', 'what', 'could', 'be'],
#  ['what', 'could', 'be', 'the'],
#  ['could', 'be', 'the', 'meaning'],
#  ['be', 'the', 'meaning', 'of'],
#  ['the', 'meaning', 'of', 'the'],
#  ['meaning', 'of', 'the', 'queer'],
#  ['of', 'the', 'queer', 'clay'],
#  ['the', 'queer', 'clay', 'bas'],
#  ['queer', 'clay', 'bas', 'relief'],
#  ['clay', 'bas', 'relief', 'and'],
#  ['bas', 'relief', 'and', 'the'],
#  ['relief', 'and', 'the', 'disjointed'],
#  ['and', 'the', 'disjointed', 'jottings'],
#  ['the', 'disjointed', 'jottings', 'ramblings'],
#  ['disjointed', 'jottings', 'ramblings', 'and'],
#  ['jottings', 'ramblings', 'and', 'cuttings'],
#  ['ramblings', 'and', 'cuttings', 'which'],
#  ['and', 'cuttings', 'which', 'i'],
#  ['cuttings', 'which', 'i', 'found'],
#  ['which', 'i', 'found', 'had'],
#  ['i', 'found', 'had', 'my'],
#  ['found', 'had', 'my', 'uncle'],
#  ['had', 'my', 'uncle', 'in'],
#  ['my', 'uncle', 'in', 'his'],
#  ['uncle', 'in', 'his', 'latter'],
#  ['in', 'his', 'latter', 'years'],
#  ['his', 'latter', 'years', 'become'],
#  ['latter', 'years', 'become', 'credulous'],
#  ['years', 'become', 'credulous', 'of'],
#  ['become', 'credulous', 'of', 'the'],
#  ['credulous', 'of', 'the', 'most'],
#  ['of', 'the', 'most', 'superficial'],
#  ['the', 'most', 'superficial', 'impostures'],
#  ['most', 'superficial', 'impostures', 'i'],
#  ['superficial', 'impostures', 'i', 'resolved'],
#  ['impostures', 'i', 'resolved', 'to'],
#  ['i', 'resolved', 'to', 'search'],
#  ['resolved', 'to', 'search', 'out'],
#  ['to', 'search', 'out', 'the'],
#  ['search', 'out', 'the', 'eccentric'],
#  ['out', 'the', 'eccentric', 'sculptor'],
#  ['the', 'eccentric', 'sculptor', 'responsible'],
#  ['eccentric', 'sculptor', 'responsible', 'for'],
#  ['sculptor', 'responsible', 'for', 'this'],
#  ['responsible', 'for', 'this', 'apparent'],
#  ['for', 'this', 'apparent', 'disturbance'],
#  ['this', 'apparent', 'disturbance', 'of'],
#  ['apparent', 'disturbance', 'of', 'an'],
#  ['disturbance', 'of', 'an', 'old'],
#  ['of', 'an', 'old', 'man'],
#  ['an', 'old', 'man', "'s"],
#  ['old', 'man', "'s", 'peace'],
#  ['man', "'s", 'peace', 'of'],
#  ["'s", 'peace', 'of', 'mind'],
#  ['peace', 'of', 'mind', 'the'],
#  ['of', 'mind', 'the', 'bas'],
#  ['mind', 'the', 'bas', 'relief'],
#  ['the', 'bas', 'relief', 'was'],
#  ['bas', 'relief', 'was', 'a'],
#  ['relief', 'was', 'a', 'rough'],
#  ['was', 'a', 'rough', 'rectangle'],
#  ['a', 'rough', 'rectangle', 'less'],
#  ['rough', 'rectangle', 'less', 'than'],
#  ['rectangle', 'less', 'than', 'an'],
#  ['less', 'than', 'an', 'inch'],
#  ['than', 'an', 'inch', 'thick'],
#  ['an', 'inch', 'thick', 'and'],
#  ['inch', 'thick', 'and', 'about'],
#  ['thick', 'and', 'about', 'five'],
#  ['and', 'about', 'five', 'by'],
#  ['about', 'five', 'by', 'six'],
#  ['five', 'by', 'six', 'inches'],
#  ['by', 'six', 'inches', 'in'],
#  ['six', 'inches', 'in', 'area'],
#  ['inches', 'in', 'area', 'obviously'],
#  ['in', 'area', 'obviously', 'of'],
#  ['area', 'obviously', 'of', 'modern'],
#  ['obviously', 'of', 'modern', 'origin'],
#  ['of', 'modern', 'origin', 'its'],
#  ['modern', 'origin', 'its', 'designs'],
#  ['origin', 'its', 'designs', 'however'],
#  ['its', 'designs', 'however', 'were'],
#  ['designs', 'however', 'were', 'far'],
#  ['however', 'were', 'far', 'from'],
#  ['were', 'far', 'from', 'modern'],
#  ['far', 'from', 'modern', 'in'],
#  ['from', 'modern', 'in', 'atmosphere'],
#  ['modern', 'in', 'atmosphere', 'and'],
#  ['in', 'atmosphere', 'and', 'suggestion'],
#  ['atmosphere', 'and', 'suggestion', 'for'],
#  ['and', 'suggestion', 'for', 'although'],
#  ['suggestion', 'for', 'although', 'the'],
#  ['for', 'although', 'the', 'vagaries'],
#  ['although', 'the', 'vagaries', 'of'],
#  ['the', 'vagaries', 'of', 'cubism'],
#  ['vagaries', 'of', 'cubism', 'and'],
#  ['of', 'cubism', 'and', 'futurism'],
#  ['cubism', 'and', 'futurism', 'are'],
#  ['and', 'futurism', 'are', 'many'],
#  ['futurism', 'are', 'many', 'and'],
#  ['are', 'many', 'and', 'wild'],
#  ['many', 'and', 'wild', 'they'],
#  ['and', 'wild', 'they', 'do'],
#  ['wild', 'they', 'do', 'not'],
#  ['they', 'do', 'not', 'often'],
#  ['do', 'not', 'often', 'reproduce'],
#  ['not', 'often', 'reproduce', 'that'],
#  ['often', 'reproduce', 'that', 'cryptic'],
#  ['reproduce', 'that', 'cryptic', 'regularity'],
#  ['that', 'cryptic', 'regularity', 'which'],
#  ['cryptic', 'regularity', 'which', 'lurks'],
#  ['regularity', 'which', 'lurks', 'in'],
#  ['which', 'lurks', 'in', 'prehistoric'],
#  ['lurks', 'in', 'prehistoric', 'writing'],
#  ['in', 'prehistoric', 'writing', 'and'],
#  ['prehistoric', 'writing', 'and', 'writing'],
#  ['writing', 'and', 'writing', 'of'],
#  ['and', 'writing', 'of', 'some'],
#  ['writing', 'of', 'some', 'kind'],
#  ['of', 'some', 'kind', 'the'],
#  ['some', 'kind', 'the', 'bulk'],
#  ['kind', 'the', 'bulk', 'of'],
#  ['the', 'bulk', 'of', 'these'],
#  ['bulk', 'of', 'these', 'designs'],
#  ['of', 'these', 'designs', 'seemed'],
#  ['these', 'designs', 'seemed', 'certainly'],
#  ['designs', 'seemed', 'certainly', 'to'],
#  ['seemed', 'certainly', 'to', 'be'],
#  ['certainly', 'to', 'be', 'though'],
#  ['to', 'be', 'though', 'my'],
#  ['be', 'though', 'my', 'memory'],
#  ['though', 'my', 'memory', 'despite'],
#  ['my', 'memory', 'despite', 'much'],
#  ['memory', 'despite', 'much', 'the'],
#  ['despite', 'much', 'the', 'papers'],
#  ['much', 'the', 'papers', 'and'],
#  ['the', 'papers', 'and', 'collections'],
#  ['papers', 'and', 'collections', 'of'],
#  ['and', 'collections', 'of', 'my'],
#  ['collections', 'of', 'my', 'uncle'],
#  ['of', 'my', 'uncle', 'failed'],
#  ['my', 'uncle', 'failed', 'in'],
#  ['uncle', 'failed', 'in', 'any'],
#  ['failed', 'in', 'any', 'way'],
#  ['in', 'any', 'way', 'to'],
#  ['any', 'way', 'to', 'identify'],
#  ['way', 'to', 'identify', 'this'],
#  ['to', 'identify', 'this', 'particular'],
#  ['identify', 'this', 'particular', 'species'],
#  ['this', 'particular', 'species', 'or'],
#  ['particular', 'species', 'or', 'even'],
#  ['species', 'or', 'even', 'hint'],
#  ['or', 'even', 'hint', 'at'],
#  ['even', 'hint', 'at', 'its'],
#  ['hint', 'at', 'its', 'remotest'],
#  ['at', 'its', 'remotest', 'affiliations'],
#  ['its', 'remotest', 'affiliations', 'above'],
#  ['remotest', 'affiliations', 'above', 'these'],
#  ['affiliations', 'above', 'these', 'apparent'],
#  ['above', 'these', 'apparent', 'hieroglyphics'],
#  ['these', 'apparent', 'hieroglyphics', 'was'],
#  ['apparent', 'hieroglyphics', 'was', 'a'],
#  ['hieroglyphics', 'was', 'a', 'figure'],
#  ['was', 'a', 'figure', 'of'],
#  ['a', 'figure', 'of', 'evident'],
#  ['figure', 'of', 'evident', 'pictorial'],
#  ['of', 'evident', 'pictorial', 'intent'],
#  ['evident', 'pictorial', 'intent', 'though'],
#  ['pictorial', 'intent', 'though', 'its'],
#  ['intent', 'though', 'its', 'impressionistic'],
#  ['though', 'its', 'impressionistic', 'execution'],
#  ['its', 'impressionistic', 'execution', 'forbade'],
#  ['impressionistic', 'execution', 'forbade', 'a'],
#  ['execution', 'forbade', 'a', 'very'],
#  ['forbade', 'a', 'very', 'clear'],
#  ['a', 'very', 'clear', 'idea'],
#  ['very', 'clear', 'idea', 'of'],
#  ['clear', 'idea', 'of', 'its'],
#  ['idea', 'of', 'its', 'nature'],
#  ['of', 'its', 'nature', 'it'],
#  ['its', 'nature', 'it', 'seemed'],
#  ['nature', 'it', 'seemed', 'to'],
#  ['it', 'seemed', 'to', 'be'],
#  ['seemed', 'to', 'be', 'a'],
#  ['to', 'be', 'a', 'sort'],
#  ['be', 'a', 'sort', 'of'],
#  ['a', 'sort', 'of', 'monster'],
#  ['sort', 'of', 'monster', 'or'],
#  ['of', 'monster', 'or', 'symbol'],
#  ['monster', 'or', 'symbol', 'representing'],
#  ['or', 'symbol', 'representing', 'a'],
#  ['symbol', 'representing', 'a', 'monster'],
#  ['representing', 'a', 'monster', 'of'],
#  ['a', 'monster', 'of', 'a'],
#  ['monster', 'of', 'a', 'form'],
#  ['of', 'a', 'form', 'which'],
#  ['a', 'form', 'which', 'only'],
#  ['form', 'which', 'only', 'a'],
#  ['which', 'only', 'a', 'diseased'],
#  ['only', 'a', 'diseased', 'fancy'],
#  ['a', 'diseased', 'fancy', 'could'],
#  ['diseased', 'fancy', 'could', 'conceive'],
#  ['fancy', 'could', 'conceive', 'if'],
#  ['could', 'conceive', 'if', 'i'],
#  ['conceive', 'if', 'i', 'say'],
#  ['if', 'i', 'say', 'that'],
#  ['i', 'say', 'that', 'my'],
#  ['say', 'that', 'my', 'somewhat'],
#  ['that', 'my', 'somewhat', 'extravagant'],
#  ['my', 'somewhat', 'extravagant', 'imagination'],
#  ['somewhat', 'extravagant', 'imagination', 'yielded'],
#  ['extravagant', 'imagination', 'yielded', 'simultaneous'],
#  ['imagination', 'yielded', 'simultaneous', 'pictures'],
#  ['yielded', 'simultaneous', 'pictures', 'of'],
#  ['simultaneous', 'pictures', 'of', 'an'],
#  ['pictures', 'of', 'an', 'octopus'],
#  ['of', 'an', 'octopus', 'a'],
#  ['an', 'octopus', 'a', 'dragon'],
#  ['octopus', 'a', 'dragon', 'and'],
#  ['a', 'dragon', 'and', 'a'],
#  ['dragon', 'and', 'a', 'human'],
#  ['and', 'a', 'human', 'caricature'],
#  ['a', 'human', 'caricature', 'i'],
#  ['human', 'caricature', 'i', 'shall'],
#  ['caricature', 'i', 'shall', 'not'],
#  ['i', 'shall', 'not', 'be'],
#  ['shall', 'not', 'be', 'unfaithful'],
#  ['not', 'be', 'unfaithful', 'to'],
#  ['be', 'unfaithful', 'to', 'the'],
#  ['unfaithful', 'to', 'the', 'spirit'],
#  ['to', 'the', 'spirit', 'of'],
#  ['the', 'spirit', 'of', 'the'],
#  ['spirit', 'of', 'the', 'thing'],
#  ['of', 'the', 'thing', 'a'],
#  ['the', 'thing', 'a', 'pulpy'],
#  ['thing', 'a', 'pulpy', 'tentacled'],
#  ['a', 'pulpy', 'tentacled', 'head'],
#  ['pulpy', 'tentacled', 'head', 'surmounted'],
#  ['tentacled', 'head', 'surmounted', 'a'],
#  ['head', 'surmounted', 'a', 'grotesque'],
#  ['surmounted', 'a', 'grotesque', 'and'],
#  ['a', 'grotesque', 'and', 'scaly'],
#  ['grotesque', 'and', 'scaly', 'body'],
#  ['and', 'scaly', 'body', 'with'],
#  ['scaly', 'body', 'with', 'rudimentary'],
#  ['body', 'with', 'rudimentary', 'wings'],
#  ['with', 'rudimentary', 'wings', 'but'],
#  ['rudimentary', 'wings', 'but', 'it'],
#  ['wings', 'but', 'it', 'was'],
#  ['but', 'it', 'was', 'the'],
#  ['it', 'was', 'the', 'general'],
#  ['was', 'the', 'general', 'outline'],
#  ['the', 'general', 'outline', 'of'],
#  ['general', 'outline', 'of', 'the'],
#  ['outline', 'of', 'the', 'whole'],
#  ['of', 'the', 'whole', 'which'],
#  ['the', 'whole', 'which', 'made'],
#  ['whole', 'which', 'made', 'it'],
#  ['which', 'made', 'it', 'most'],
#  ['made', 'it', 'most', 'shockingly'],
#  ['it', 'most', 'shockingly', 'frightful'],
#  ['most', 'shockingly', 'frightful', 'behind'],
#  ['shockingly', 'frightful', 'behind', 'the'],
#  ['frightful', 'behind', 'the', 'figure'],
#  ['behind', 'the', 'figure', 'was'],
#  ['the', 'figure', 'was', 'a'],
#  ['figure', 'was', 'a', 'vague'],
#  ['was', 'a', 'vague', 'suggestions'],
#  ['a', 'vague', 'suggestions', 'of'],
#  ['vague', 'suggestions', 'of', 'a'],
#  ['suggestions', 'of', 'a', 'cyclopean'],
#  ['of', 'a', 'cyclopean', 'architectural'],
#  ['a', 'cyclopean', 'architectural', 'background'],
#  ['cyclopean', 'architectural', 'background', 'the'],
#  ['architectural', 'background', 'the', 'writing'],
#  ['background', 'the', 'writing', 'accompanying'],
#  ['the', 'writing', 'accompanying', 'this'],
#  ['writing', 'accompanying', 'this', 'oddity'],
#  ['accompanying', 'this', 'oddity', 'was'],
#  ['this', 'oddity', 'was', 'aside'],
#  ['oddity', 'was', 'aside', 'from'],
#  ['was', 'aside', 'from', 'a'],
#  ['aside', 'from', 'a', 'stack'],
#  ['from', 'a', 'stack', 'of'],
#  ['a', 'stack', 'of', 'press'],
#  ['stack', 'of', 'press', 'cuttings'],
#  ['of', 'press', 'cuttings', 'in'],
#  ['press', 'cuttings', 'in', 'professor'],
#  ['cuttings', 'in', 'professor', 'angell'],
#  ['in', 'professor', 'angell', "'s"],
#  ['professor', 'angell', "'s", 'most'],
#  ['angell', "'s", 'most', 'recent'],
#  ["'s", 'most', 'recent', 'hand'],
#  ['most', 'recent', 'hand', 'and'],
#  ['recent', 'hand', 'and', 'made'],
#  ['hand', 'and', 'made', 'no'],
#  ['and', 'made', 'no', 'pretense'],
#  ['made', 'no', 'pretense', 'to'],
#  ['no', 'pretense', 'to', 'literary'],
#  ['pretense', 'to', 'literary', 'style'],
#  ['to', 'literary', 'style', 'what'],
#  ['literary', 'style', 'what', 'seemed'],
#  ['style', 'what', 'seemed', 'to'],
#  ['what', 'seemed', 'to', 'be'],
#  ['seemed', 'to', 'be', 'the'],
#  ['to', 'be', 'the', 'main'],
#  ['be', 'the', 'main', 'document'],
#  ['the', 'main', 'document', 'was'],
#  ['main', 'document', 'was', 'headed'],
#  ['document', 'was', 'headed', 'cthulhu'],
#  ['was', 'headed', 'cthulhu', 'cult'],
#  ['headed', 'cthulhu', 'cult', 'in'],
#  ['cthulhu', 'cult', 'in', 'characters'],
#  ['cult', 'in', 'characters', 'painstakingly'],
#  ['in', 'characters', 'painstakingly', 'printed'],
#  ['characters', 'painstakingly', 'printed', 'to'],
#  ['painstakingly', 'printed', 'to', 'avoid'],
#  ['printed', 'to', 'avoid', 'the'],
#  ['to', 'avoid', 'the', 'erroneous'],
#  ['avoid', 'the', 'erroneous', 'reading'],
#  ['the', 'erroneous', 'reading', 'of'],
#  ...]

# %% [markdown]
# 1.2 - Crear los vectores de palabras (word2vec)
#
# Ahora necesitamos pasarlos a números para que lo entienda la red y separar input de output.
# - El Input seran integers (word2vec)
# - Mientras que el output será one hot encodeado (labels) del tamaño del vocabulario

# %%
tok = Tokenizer()

# El tokeinzer "aprende" las palabras que se usaran
# Se construye (fit) una vez por proyecto, se aplica N veces (tal cual un encoder)
tok.fit_on_texts(text_sequences)

# Convertimos las palabras a números
# entran palabras -> salen números
sequences = tok.texts_to_sequences(text_sequences)

# %%
# Ahora sequences tiene los números "ID", largo 4
sequences
# Out:
# [[3155, 454, 2, 58],
#  [454, 2, 58, 21],
#  [2, 58, 21, 682],
#  [58, 21, 682, 683],
#  [21, 682, 683, 1201],
#  [682, 683, 1201, 1],
#  [683, 1201, 1, 454],
#  [1201, 1, 454, 2],
#  [1, 454, 2, 58],
#  [454, 2, 58, 2],
#  [2, 58, 2, 135],
#  [58, 2, 135, 44],
#  [2, 135, 44, 1202],
#  [135, 44, 1202, 32],
#  [44, 1202, 32, 684],
#  [1202, 32, 684, 42],
#  [32, 684, 42, 136],
#  [684, 42, 136, 30],
#  [42, 136, 30, 1203],
#  [136, 30, 1203, 4],
#  [30, 1203, 4, 685],
#  [1203, 4, 685, 4],
#  [4, 685, 4, 685],
#  [685, 4, 685, 2],
#  [4, 685, 2, 4],
#  [685, 2, 4, 1204],
#  [2, 4, 1204, 686],
#  [4, 1204, 686, 259],
#  [1204, 686, 259, 51],
#  [686, 259, 51, 687],
#  [259, 51, 687, 7],
#  [51, 687, 7, 688],
#  [687, 7, 688, 455],
#  [7, 688, 455, 5],
#  [688, 455, 5, 456],
#  [455, 5, 456, 3],
#  [5, 456, 3, 689],
#  [456, 3, 689, 137],
#  [3, 689, 137, 210],
#  [689, 137, 210, 1205],
#  [137, 210, 1205, 67],
#  [210, 1205, 67, 1],
#  [1205, 67, 1, 1206],
#  [67, 1, 1206, 2],
#  [1, 1206, 2, 1207],
#  [1206, 2, 1207, 1208],
#  [2, 1207, 1208, 689],
#  [1207, 1208, 689, 2],
#  [1208, 689, 2, 14],
#  [689, 2, 14, 690],
#  [2, 14, 690, 3],
#  [14, 690, 3, 691],
#  [690, 3, 691, 184],
#  [3, 691, 184, 33],
#  [691, 184, 33, 692],
#  [184, 33, 692, 4],
#  [33, 692, 4, 1209],
#  [692, 4, 1209, 260],
#  [4, 1209, 260, 3],
#  [1209, 260, 3, 261],
#  [260, 3, 261, 47],
#  [3, 261, 47, 693],
#  [261, 47, 693, 1210],
#  [47, 693, 1210, 1211],
#  [693, 1210, 1211, 684],
#  [1210, 1211, 684, 2],
#  [1211, 684, 2, 28],
#  [684, 2, 28, 1212],
#  [2, 28, 1212, 3],
#  [28, 1212, 3, 1213],
#  [1212, 3, 1213, 694],
#  [3, 1213, 694, 1214],
#  [1213, 694, 1214, 1215],
#  [694, 1214, 1215, 111],
#  [1214, 1215, 111, 10],
#  [1215, 111, 10, 1],
#  [111, 10, 1, 185],
#  [10, 1, 185, 5],
#  [1, 185, 5, 329],
#  [185, 5, 329, 1],
#  [5, 329, 1, 168],
#  [329, 1, 168, 1216],
#  [1, 168, 1216, 70],
#  [168, 1216, 70, 5],
#  [1216, 70, 5, 1],
#  [70, 5, 1, 105],
#  [5, 1, 105, 10],
#  [1, 105, 10, 128],
#  [105, 10, 128, 53],
#  [10, 128, 53, 1],
#  [128, 53, 1, 1217],
#  [53, 1, 1217, 2],
#  [1, 1217, 2, 1],
#  [1217, 2, 1, 262],
#  [2, 1, 262, 211],
#  [1, 262, 211, 6],
#  [262, 211, 6, 1218],
#  [38, 37, 466, 114],
#  [37, 466, 114, 1251],
#  [466, 114, 1251, 25],
#  [114, 1251, 25, 459],
#  [1251, 25, 459, 65],
#  [25, 459, 65, 713],
#  [459, 65, 713, 107],
#  [65, 713, 107, 10],
#  [713, 107, 10, 457],
#  [107, 10, 457, 10],
#  [10, 457, 10, 152],
#  [457, 10, 152, 85],
#  [10, 152, 85, 1252],
#  [152, 85, 1252, 1253],
#  [85, 1252, 1253, 4],
#  [1252, 1253, 4, 714],
#  [1253, 4, 714, 5],
#  [4, 714, 5, 46],
#  [714, 5, 46, 153],
#  [5, 46, 153, 4],
#  [46, 153, 4, 1254],
#  [153, 4, 1254, 10],
#  [4, 1254, 10, 128],
#  [1254, 10, 128, 9],
#  [10, 128, 9, 1],
#  [128, 9, 1, 45],
#  [9, 1, 45, 116],
#  [1, 45, 116, 1255],
#  [45, 116, 1255, 6],
#  [116, 1255, 6, 467],
#  [1255, 6, 467, 1256],
#  [6, 467, 1256, 715],
#  [467, 1256, 715, 1],
#  [1256, 715, 1, 111],
#  [715, 1, 111, 12],
#  [1, 111, 12, 154],
#  [111, 12, 154, 3],
#  [12, 154, 3, 9],
#  [154, 3, 9, 12],
#  [3, 9, 12, 54],
#  [9, 12, 54, 33],
#  [12, 54, 33, 1257],
#  [54, 33, 1257, 13],
#  [33, 1257, 13, 129],
#  [1257, 13, 129, 8],
#  [13, 129, 8, 24],
#  [129, 8, 24, 1258],
#  [8, 24, 1258, 139],
#  [24, 1258, 139, 1259],
#  [1258, 139, 1259, 52],
#  [139, 1259, 52, 26],
#  [1259, 52, 26, 264],
#  [52, 26, 264, 2],
#  [26, 264, 2, 1],
#  [264, 2, 1, 70],
#  [2, 1, 70, 140],
#  [1, 70, 140, 5],
#  [70, 140, 5, 1],
#  [140, 5, 1, 1260],
#  [5, 1, 1260, 2],
#  [1, 1260, 2, 716],
#  [1260, 2, 716, 1261],
#  [2, 716, 1261, 15],
#  [716, 1261, 15, 1],
#  [1261, 15, 1, 139],
#  [15, 1, 139, 2],
#  [1, 139, 2, 26],
#  [139, 2, 26, 44],
#  [2, 26, 44, 55],
#  [26, 44, 55, 1262],
#  [44, 55, 1262, 1263],
#  [55, 1262, 1263, 93],
#  [1262, 1263, 93, 45],
#  [1263, 93, 45, 1264],
#  [93, 45, 1264, 2],
#  [45, 1264, 2, 1265],
#  [1264, 2, 1265, 1266],
#  [2, 1265, 1266, 5],
#  [1265, 1266, 5, 1267],
#  [1266, 5, 1267, 339],
#  [5, 1267, 339, 340],
#  [1267, 339, 340, 717],
#  [339, 340, 717, 169],
#  [340, 717, 169, 45],
#  [717, 169, 45, 93],
#  [169, 45, 93, 7],
#  [45, 93, 7, 468],
#  [93, 7, 468, 99],
#  [7, 468, 99, 20],
#  [468, 99, 20, 29],
#  [99, 20, 29, 718],
#  [20, 29, 718, 18],
#  [29, 718, 18, 141],
#  [718, 18, 141, 719],
#  [18, 141, 719, 3],
#  [141, 719, 3, 8],
#  [719, 3, 8, 720],
#  [3, 8, 720, 49],
#  [8, 720, 49, 1268],
#  [720, 49, 1268, 6],
#  [49, 1268, 6, 21],
#  [1268, 6, 21, 1],
#  [6, 21, 1, 721],
#  [21, 1, 721, 2],
#  [1, 721, 2, 722],
#  [721, 2, 722, 1269],
#  [2, 722, 1269, 46],
#  [722, 1269, 46, 9],
#  [1269, 46, 9, 13],
#  [46, 9, 13, 1270],
#  [9, 13, 1270, 19],
#  [13, 1270, 19, 1],
#  [1270, 19, 1, 266],
#  [19, 1, 266, 2],
#  [1, 266, 2, 1271],
#  [266, 2, 1271, 117],
#  [2, 1271, 117, 136],
#  [1271, 117, 136, 30],
#  [117, 136, 30, 1272],
#  [136, 30, 1272, 21],
#  [30, 1272, 21, 267],
#  [1272, 21, 267, 1273],
#  [21, 267, 1273, 215],
#  [267, 1273, 215, 7],
#  [1273, 215, 7, 723],
#  [215, 7, 723, 21],
#  [7, 723, 21, 1],
#  [723, 21, 1, 1274],
#  [21, 1, 1274, 2],
#  [1, 1274, 2, 1],
#  [1274, 2, 1, 469],
#  [2, 1, 469, 2],
#  [1, 469, 2, 139],
#  [469, 2, 139, 1],
#  [2, 139, 1, 45],
#  [139, 1, 45, 8],
#  [1, 45, 8, 49],
#  [45, 8, 49, 724],
#  [8, 49, 724, 118],
#  [49, 724, 118, 1275],
#  [724, 118, 1275, 16],
#  [118, 1275, 16, 1],
#  [1275, 16, 1, 1276],
#  [16, 1, 1276, 341],
#  [1, 1276, 341, 470],
#  [1276, 341, 470, 268],
#  [341, 470, 268, 20],
#  [470, 268, 20, 1277],
#  [268, 20, 1277, 86],
#  [20, 1277, 86, 61],
#  [1277, 86, 61, 155],
#  [86, 61, 155, 49],
#  [61, 155, 49, 1278],
#  [155, 49, 1278, 21],
#  [49, 1278, 21, 4],
#  [1278, 21, 4, 1279],
#  [21, 4, 1279, 342],
#  [4, 1279, 342, 471],
#  [1279, 342, 471, 71],
#  [342, 471, 71, 8],
#  [471, 71, 8, 87],
#  [71, 8, 87, 16],
#  [8, 87, 16, 37],
#  [87, 16, 37, 2],
#  [16, 37, 2, 1],
#  [37, 2, 1, 170],
#  [2, 1, 170, 106],
#  [1, 170, 106, 1280],
#  [170, 106, 1280, 18],
#  [106, 1280, 18, 1],
#  [1280, 18, 1, 1281],
#  [18, 1, 1281, 1282],
#  [1, 1281, 1282, 14],
#  [1281, 1282, 14, 188],
#  [1282, 14, 188, 4],
#  [14, 188, 4, 472],
#  [188, 4, 472, 343],
#  [4, 472, 343, 16],
#  [472, 343, 16, 1],
#  [343, 16, 1, 344],
#  [16, 1, 344, 6],
#  [1, 344, 6, 1],
#  [344, 6, 1, 1283],
#  [6, 1, 1283, 23],
#  [1, 1283, 23, 269],
#  [1283, 23, 269, 5],
#  [23, 269, 5, 1284],
#  [269, 5, 1284, 189],
#  [5, 1284, 189, 725],
#  [1284, 189, 725, 27],
#  [189, 725, 27, 1285],
#  [725, 27, 1285, 6],
#  [27, 1285, 6, 345],
#  [1285, 6, 345, 88],
#  [6, 345, 88, 346],
#  [345, 88, 346, 726],
#  [88, 346, 726, 22],
#  [346, 726, 22, 1286],
#  [726, 22, 1286, 61],
#  [22, 1286, 61, 1287],
#  [1286, 61, 1287, 1288],
#  [61, 1287, 1288, 9],
#  [1287, 1288, 9, 35],
#  [1288, 9, 35, 727],
#  [9, 35, 727, 1289],
#  [35, 727, 1289, 2],
#  [727, 1289, 2, 1],
#  [1289, 2, 1, 473],
#  [2, 1, 473, 728],
#  [1, 473, 728, 21],
#  [473, 728, 21, 1],
#  [728, 21, 1, 1290],
#  [21, 1, 1290, 1291],
#  [1, 1290, 1291, 2],
#  [1290, 1291, 2, 46],
#  [1291, 2, 46, 1292],
#  [2, 46, 1292, 4],
#  [46, 1292, 4, 474],
#  [1292, 4, 474, 21],
#  [4, 474, 21, 46],
#  [474, 21, 46, 1293],
#  [21, 46, 1293, 4],
#  [46, 1293, 4, 62],
#  [1293, 4, 62, 7],
#  [4, 62, 7, 729],
#  [62, 7, 729, 17],
#  [7, 729, 17, 1],
#  [729, 17, 1, 190],
#  [17, 1, 190, 19],
#  [1, 190, 19, 1],
#  [190, 19, 1, 74],
#  [19, 1, 74, 10],
#  [1, 74, 10, 171],
#  [74, 10, 171, 38],
#  [10, 171, 38, 475],
#  [171, 38, 475, 6],
#  [38, 475, 6, 1294],
#  [475, 6, 1294, 16],
#  [6, 1294, 16, 25],
#  [1294, 16, 25, 1295],
#  [16, 25, 1295, 22],
#  [25, 1295, 22, 730],
#  [1295, 22, 730, 10],
#  [22, 730, 10, 731],
#  [730, 10, 731, 1296],
#  [10, 731, 1296, 6],
#  [731, 1296, 6, 1297],
#  [1296, 6, 1297, 59],
#  [6, 1297, 59, 72],
#  [1297, 59, 72, 270],
#  [59, 72, 270, 20],
#  [72, 270, 20, 26],
#  [270, 20, 26, 44],
#  [20, 26, 44, 55],
#  [26, 44, 55, 23],
#  [44, 55, 23, 1298],
#  [55, 23, 1298, 3],
#  [23, 1298, 3, 1299],
#  [1298, 3, 1299, 17],
#  [3, 1299, 17, 12],
#  [1299, 17, 12, 172],
#  [17, 12, 172, 4],
#  [12, 172, 4, 1300],
#  [172, 4, 1300, 1301],
#  [4, 1300, 1301, 10],
#  [1300, 1301, 10, 7],
#  [1301, 10, 7, 732],
#  [10, 7, 732, 6],
#  [7, 732, 6, 212],
#  [732, 6, 212, 100],
#  [6, 212, 100, 13],
#  [212, 100, 13, 216],
#  [100, 13, 216, 15],
#  [13, 216, 15, 35],
#  [216, 15, 35, 733],
#  [15, 35, 733, 3],
#  [35, 733, 3, 17],
#  [733, 3, 17, 9],
#  [3, 17, 9, 1302],
#  [17, 9, 1302, 476],
#  [9, 1302, 476, 13],
#  [1302, 476, 13, 734],
#  [476, 13, 734, 217],
#  [13, 734, 217, 2],
#  [734, 217, 2, 1303],
#  [217, 2, 1303, 3],
#  [2, 1303, 3, 1304],
#  [1303, 3, 1304, 6],
#  [3, 1304, 6, 26],
#  [1304, 6, 26, 477],
#  [6, 26, 477, 5],
#  [26, 477, 5, 1305],
#  [477, 5, 1305, 108],
#  [5, 1305, 108, 2],
#  [1305, 108, 2, 1],
#  [108, 2, 1, 191],
#  [2, 1, 191, 14],
#  [1, 191, 14, 10],
#  [191, 14, 10, 1306],
#  [14, 10, 1306, 114],
#  [10, 1306, 114, 30],
#  [1306, 114, 30, 271],
#  [114, 30, 271, 1307],
#  [30, 271, 1307, 21],
#  [271, 1307, 21, 1],
#  [1307, 21, 1, 735],
#  [21, 1, 735, 736],
#  [1, 735, 736, 272],
#  [735, 736, 272, 22],
#  [736, 272, 22, 42],
#  [272, 22, 42, 7],
#  [22, 42, 7, 37],
#  [42, 7, 37, 737],
#  [7, 37, 737, 14],
#  [37, 737, 14, 10],
#  [737, 14, 10, 69],
#  [14, 10, 69, 478],
#  [10, 69, 478, 1308],
#  [69, 478, 1308, 3],
#  [478, 1308, 3, 14],
#  [1308, 3, 14, 10],
#  [3, 14, 10, 142],
#  [14, 10, 142, 108],
#  [10, 142, 108, 1309],
#  [142, 108, 1309, 16],
#  [108, 1309, 16, 1310],
#  [1309, 16, 1310, 6],
#  [16, 1310, 6, 130],
#  [1310, 6, 130, 479],
#  [6, 130, 479, 11],
#  [130, 479, 11, 8],
#  [479, 11, 8, 49],
#  [11, 8, 49, 738],
#  [8, 49, 738, 3],
#  [49, 738, 3, 10],
#  [738, 3, 10, 109],
#  [3, 10, 109, 24],
#  [10, 109, 24, 345],
#  [109, 24, 345, 1],
#  [24, 345, 1, 739],
#  [345, 1, 739, 273],
#  [1, 739, 273, 11],
#  [739, 273, 11, 1311],
#  [273, 11, 1311, 6],
#  [11, 1311, 6, 68],
#  [1311, 6, 68, 6],
#  [6, 68, 6, 1312],
#  [68, 6, 1312, 1],
#  [6, 1312, 1, 480],
#  [1312, 1, 480, 274],
#  [1, 480, 274, 14],
#  [480, 274, 14, 1],
#  [274, 14, 1, 45],
#  [14, 1, 45, 481],
#  [1, 45, 481, 5],
#  [45, 481, 5, 13],
#  [481, 5, 13, 1313],
#  [5, 13, 1313, 63],
#  [13, 1313, 63, 143],
#  [1313, 63, 143, 10],
#  [63, 143, 10, 740],
#  [143, 10, 740, 5],
#  [10, 740, 5, 1314],
#  [740, 5, 1314, 11],
#  [5, 1314, 11, 22],
#  [1314, 11, 22, 51],
#  [11, 22, 51, 10],
#  [22, 51, 10, 109],
#  [51, 10, 109, 46],
#  [10, 109, 46, 119],
#  [109, 46, 119, 50],
#  [46, 119, 50, 6],
#  [119, 50, 6, 30],
#  [50, 6, 30, 1315],
#  [6, 30, 1315, 21],
#  [30, 1315, 21, 4],
#  [1315, 21, 4, 741],
#  [21, 4, 741, 3],
#  [4, 741, 3, 59],
#  [741, 3, 59, 1316],
#  [3, 59, 1316, 738],
#  [59, 1316, 738, 1317],
#  [1316, 738, 1317, 17],
#  [738, 1317, 17, 43],
#  [1317, 17, 43, 36],
#  [17, 43, 36, 30],
#  [43, 36, 30, 1],
#  [36, 30, 1, 1318],
#  [30, 1, 1318, 2],
#  [1, 1318, 2, 1],
#  [1318, 2, 1, 170],
#  [2, 1, 170, 329],
#  [1, 170, 329, 120],
#  [170, 329, 120, 131],
#  [329, 120, 131, 3],
#  [120, 131, 3, 1],
#  [131, 3, 1, 1319],
#  [3, 1, 1319, 1320],
#  [1, 1319, 1320, 1321],
#  [1319, 1320, 1321, 3],
#  [1320, 1321, 3, 192],
#  [1321, 3, 192, 14],
#  [3, 192, 14, 10],
#  [192, 14, 10, 69],
#  [14, 10, 69, 8],
#  [10, 69, 8, 26],
#  [69, 8, 26, 55],
#  [8, 26, 55, 5],
#  [26, 55, 5, 13],
#  [55, 5, 13, 482],
#  [5, 13, 482, 173],
#  [13, 482, 173, 742],
#  [482, 173, 742, 1322],
#  [173, 742, 1322, 2],
#  [742, 1322, 2, 1],
#  [1322, 2, 1, 168],
#  [2, 1, 168, 1323],
#  [1, 168, 1323, 1324],
#  [168, 1323, 1324, 10],
#  [1323, 1324, 10, 347],
#  [1324, 10, 347, 6],
#  [10, 347, 6, 743],
#  [347, 6, 743, 65],
#  [6, 743, 65, 1],
#  [743, 65, 1, 1325],
#  [65, 1, 1325, 132],
#  [1, 1325, 132, 729],
#  [1325, 132, 729, 17],
#  [132, 729, 17, 25],
#  [729, 17, 25, 483],
#  [17, 25, 483, 1326],
#  [25, 483, 1326, 2],
#  [483, 1326, 2, 29],
#  [1326, 2, 29, 48],
#  [2, 29, 48, 62],
#  [29, 48, 62, 23],
#  [48, 62, 23, 701],
#  [62, 23, 701, 2],
#  [23, 701, 2, 211],
#  [701, 2, 211, 1],
#  [2, 211, 1, 120],
#  [211, 1, 120, 131],
#  [1, 120, 131, 7],
#  [120, 131, 7, 4],
#  [131, 7, 4, 484],
#  [7, 4, 484, 1327],
#  [4, 484, 1327, 348],
#  [484, 1327, 348, 72],
#  [1327, 348, 72, 29],
#  [348, 72, 29, 744],
#  [72, 29, 744, 1328],
#  [29, 744, 1328, 3],
#  [744, 1328, 3, 89],
#  [1328, 3, 89, 485],
#  [3, 89, 485, 21],
#  [89, 485, 21, 275],
#  [485, 21, 275, 745],
#  [21, 275, 745, 5],
#  [275, 745, 5, 746],
#  [745, 5, 746, 1329],
#  [5, 746, 1329, 2],
#  [746, 1329, 2, 747],
#  [1329, 2, 747, 276],
#  [2, 747, 276, 34],
#  [747, 276, 34, 748],
#  [276, 34, 748, 349],
#  [34, 748, 349, 27],
#  [748, 349, 27, 113],
#  [349, 27, 113, 16],
#  [27, 113, 16, 747],
#  [113, 16, 747, 5],
#  [16, 747, 5, 1330],
#  [747, 5, 1330, 3],
#  [5, 1330, 3, 749],
#  [1330, 3, 749, 17],
#  [3, 749, 17, 277],
#  [749, 17, 277, 1],
#  [17, 277, 1, 1331],
#  [277, 1, 1331, 2],
#  [1, 1331, 2, 1332],
#  [1331, 2, 1332, 3],
#  [2, 1332, 3, 750],
#  [1332, 3, 750, 278],
#  [3, 750, 278, 267],
#  [750, 278, 267, 3],
#  [278, 267, 3, 350],
#  [267, 3, 350, 31],
#  [3, 350, 31, 218],
#  [350, 31, 218, 24],
#  [31, 218, 24, 486],
#  [218, 24, 486, 1333],
#  [24, 486, 1333, 9],
#  [486, 1333, 9, 487],
#  [1333, 9, 487, 1334],
#  [9, 487, 1334, 14],
#  [487, 1334, 14, 1335],
#  [1334, 14, 1335, 5],
#  [14, 1335, 5, 1336],
#  [1335, 5, 1336, 219],
#  [5, 1336, 219, 3],
#  [1336, 219, 3, 219],
#  [219, 3, 219, 2],
#  [3, 219, 2, 35],
#  [219, 2, 35, 751],
#  [2, 35, 751, 1],
#  [35, 751, 1, 488],
#  [751, 1, 488, 2],
#  [1, 488, 2, 144],
#  [488, 2, 144, 748],
#  [2, 144, 748, 119],
#  [144, 748, 119, 713],
#  [748, 119, 713, 6],
#  [119, 713, 6, 30],
#  [713, 6, 30, 101],
#  [6, 30, 101, 26],
#  [30, 101, 26, 260],
#  [101, 26, 260, 351],
#  [26, 260, 351, 108],
#  [260, 351, 108, 1],
#  [351, 108, 1, 216],
#  [108, 1, 216, 3],
#  [1, 216, 3, 1337],
#  [216, 3, 1337, 2],
#  [3, 1337, 2, 26],
#  [1337, 2, 26, 55],
#  [2, 26, 55, 352],
#  [26, 55, 352, 5],
#  [55, 352, 5, 88],
#  [352, 5, 88, 156],
#  [5, 88, 156, 6],
#  [88, 156, 6, 1338],
#  [156, 6, 1338, 25],
#  [6, 1338, 25, 752],
#  [1338, 25, 752, 1339],
#  [25, 752, 1339, 32],
#  [752, 1339, 32, 90],
#  [1339, 32, 90, 489],
#  [32, 90, 489, 19],
#  [90, 489, 19, 34],
#  [489, 19, 34, 490],
#  [19, 34, 490, 491],
#  [34, 490, 491, 492],
#  [490, 491, 492, 144],
#  [491, 492, 144, 483],
#  [492, 144, 483, 220],
#  [144, 483, 220, 7],
#  [483, 220, 7, 4],
#  [220, 7, 4, 279],
#  [7, 4, 279, 2],
#  [4, 279, 2, 1340],
#  [279, 2, 1340, 753],
#  [2, 1340, 753, 1341],
#  [1340, 753, 1341, 101],
#  [753, 1341, 101, 34],
#  [1341, 101, 34, 1342],
#  [101, 34, 1342, 1343],
#  [34, 1342, 1343, 1344],
#  [1342, 1343, 1344, 4],
#  [1343, 1344, 4, 75],
#  [1344, 4, 75, 493],
#  [4, 75, 493, 754],
#  [75, 493, 754, 2],
#  [493, 754, 2, 34],
#  [754, 2, 34, 755],
#  [2, 34, 755, 11],
#  [34, 755, 11, 119],
#  [755, 11, 119, 6],
#  [11, 119, 6, 30],
#  [119, 6, 30, 4],
#  [6, 30, 4, 494],
#  [30, 4, 494, 2],
#  [4, 494, 2, 280],
#  [494, 2, 280, 32],
#  [2, 280, 32, 756],
#  [280, 32, 756, 1345],
#  [32, 756, 1345, 4],
#  [756, 1345, 4, 280],
#  [1345, 4, 280, 2],
#  [4, 280, 2, 4],
#  [280, 2, 4, 214],
#  [2, 4, 214, 14],
#  [4, 214, 14, 50],
#  [214, 14, 50, 4],
#  [14, 50, 4, 1346],
#  [50, 4, 1346, 495],
#  [4, 1346, 495, 36],
#  [1346, 495, 36, 1347],
#  [495, 36, 1347, 107],
#  [36, 1347, 107, 10],
#  [1347, 107, 10, 757],
#  [107, 10, 757, 9],
#  [10, 757, 9, 26],
#  [757, 9, 26, 496],
#  [9, 26, 496, 1348],
#  [26, 496, 1348, 353],
#  [496, 1348, 353, 1349],
#  [1348, 353, 1349, 1350],
#  [353, 1349, 1350, 1351],
#  [1349, 1350, 1351, 2],
#  [1350, 1351, 2, 29],
#  [1351, 2, 29, 758],
#  [2, 29, 758, 4],
#  [29, 758, 4, 497],
#  [758, 4, 497, 3],
#  [4, 497, 3, 4],
#  [497, 3, 4, 262],
#  [3, 4, 262, 1352],
#  [4, 262, 1352, 10],
#  [262, 1352, 10, 152],
#  [1352, 10, 152, 24],
#  [10, 152, 24, 30],
#  [152, 24, 30, 1353],
#  [24, 30, 1353, 6],
#  [30, 1353, 6, 1],
#  [1353, 6, 1, 1354],
#  [6, 1, 1354, 2],
#  [1, 1354, 2, 1],
#  [1354, 2, 1, 70],
#  [2, 1, 70, 4],
#  [1, 70, 4, 1355],
#  [70, 4, 1355, 1356],
#  [4, 1355, 1356, 174],
#  [1355, 1356, 174, 1357],
#  [1356, 174, 1357, 4],
#  [174, 1357, 4, 498],
#  [1357, 4, 498, 3],
#  [4, 498, 3, 499],
#  [498, 3, 499, 221],
#  [3, 499, 221, 15],
#  [499, 221, 15, 1358],
#  [221, 15, 1358, 222],
#  [15, 1358, 222, 22],
#  [1358, 222, 22, 11],
#  [222, 22, 11, 7],
#  [22, 11, 7, 1],
#  [11, 7, 1, 500],
#  [7, 1, 500, 759],
#  [1, 500, 759, 2],
#  [500, 759, 2, 1],
#  [759, 2, 1, 223],
#  [2, 1, 223, 14],
#  [1, 223, 14, 91],
#  [223, 14, 91, 11],
#  [14, 91, 11, 168],
#  [91, 11, 168, 1359],
#  [11, 168, 1359, 336],
#  [168, 1359, 336, 354],
#  [1359, 336, 354, 1],
#  [336, 354, 1, 279],
#  [354, 1, 279, 7],
#  [1, 279, 7, 4],
#  [279, 7, 4, 501],
#  [7, 4, 501, 1360],
#  [4, 501, 1360, 2],
#  [501, 1360, 2, 4],
#  [1360, 2, 4, 193],
#  [2, 4, 193, 1361],
#  [4, 193, 1361, 1362],
#  [193, 1361, 1362, 1],
#  [1361, 1362, 1, 219],
#  [1362, 1, 219, 1363],
#  [1, 219, 1363, 25],
#  [219, 1363, 25, 1364],
#  [1363, 25, 1364, 7],
#  [25, 1364, 7, 502],
#  [1364, 7, 502, 16],
#  [7, 502, 16, 4],
#  [502, 16, 4, 1365],
#  [16, 4, 1365, 2],
#  [4, 1365, 2, 760],
#  [1365, 2, 760, 192],
#  [2, 760, 192, 5],
#  [760, 192, 5, 45],
#  [192, 5, 45, 93],
#  [5, 45, 93, 23],
#  [45, 93, 23, 168],
#  [93, 23, 168, 761],
#  [23, 168, 761, 762],
#  [168, 761, 762, 3],
#  [761, 762, 3, 91],
#  [762, 3, 91, 38],
#  [3, 91, 38, 1366],
#  [91, 38, 1366, 6],
#  [38, 1366, 6, 1367],
#  [1366, 6, 1367, 1368],
#  [6, 1367, 1368, 43],
#  [1367, 1368, 43, 119],
#  [1368, 43, 119, 6],
#  [43, 119, 6, 30],
#  [119, 6, 30, 1],
#  [6, 30, 1, 1369],
#  [30, 1, 1369, 503],
#  [1, 1369, 503, 7],
#  [1369, 503, 7, 763],
#  [503, 7, 763, 58],
#  [7, 763, 58, 39],
#  [763, 58, 39, 5],
#  [58, 39, 5, 504],
#  [39, 5, 504, 1370],
#  [5, 504, 1370, 1371],
#  [504, 1370, 1371, 6],
#  [1370, 1371, 6, 1372],
#  [1371, 6, 1372, 1],
#  [6, 1372, 1, 1373],
#  [1372, 1, 1373, 764],
#  [1, 1373, 764, 2],
#  ...]

# %%
# Cantidad de casos (doc) de entrada
print(tok.document_count)
# Out:
# 12011

# %%
# Cantidad de veces que aparece cada palabra
print(len(tok.word_counts))
# Out:
# 3156

# %%
# El índice para cada palabra
# El sistema las ordena de las más populares a las menos populares
print(tok.word_index)
# Out:
# {'the': 1, 'of': 2, 'and': 3, 'a': 4, 'in': 5, 'to': 6, 'was': 7, 'had': 8, 'that': 9, 'i': 10, 'it': 11, 'he': 12, 'his': 13, 'which': 14, 'with': 15, 'from': 16, 'for': 17, 'on': 18, 'at': 19, 'as': 20, 'by': 21, 'but': 22, "'s": 23, 'not': 24, 'this': 25, 'my': 26, 'were': 27, 'all': 28, 'an': 29, 'be': 30, 'they': 31, 'or': 32, 'have': 33, 'its': 34, 'some': 35, 'could': 36, 'one': 37, 'no': 38, 'cult': 39, 'their': 40, 'men': 41, 'there': 42, 'what': 43, 'great': 44, 'professor': 45, 'so': 46, 'them': 47, 'old': 48, 'been': 49, 'only': 50, 'when': 51, 'him': 52, 'is': 53, 'would': 54, 'uncle': 55, 'now': 56, 'johansen': 57, 'cthulhu': 58, 'more': 59, 'dreams': 60, 'after': 61, 'man': 62, 'then': 63, 'wilcox': 64, 'out': 65, 'legrasse': 66, 'before': 67, 'me': 68, 'found': 69, 'thing': 70, 'who': 71, 'than': 72, 'told': 73, 'time': 74, 'very': 75, 'strange': 76, 'like': 77, 'dream': 78, 'earth': 79, 'into': 80, 'came': 81, 'must': 82, 'stone': 83, 'up': 84, 'never': 85, 'said': 86, 'come': 87, 'any': 88, 'about': 89, 'even': 90, 'made': 91, 'those': 92, 'angell': 93, 'young': 94, 'city': 95, 'ones': 96, 'stars': 97, 'dead': 98, 'known': 99, 'over': 100, 'though': 101, 'first': 102, 'upon': 103, 'again': 104, 'world': 105, 'dark': 106, 'if': 107, 'much': 108, 'did': 109, 'sea': 110, 'part': 111, 'black': 112, 'far': 113, 'will': 114, 'new': 115, 'too': 116, 'two': 117, 'whilst': 118, 'seemed': 119, 'bas': 120, 'r': 121, 'half': 122, 'march': 123, 'through': 124, 'april': 125, 'down': 126, 'alert': 127, 'think': 128, 'notes': 129, 'other': 130, 'relief': 131, 'sculptor': 132, 'manuscript': 133, 'something': 134, 'such': 135, 'may': 136, 'long': 137, 'day': 138, 'death': 139, 'began': 140, 'ancient': 141, 'felt': 142, 'indeed': 143, 'these': 144, 'night': 145, 'terrible': 146, "'lyeh": 147, 'once': 148, 'image': 149, '
8, 'ancient': 40, 'inscriptions': 8, 'frequently': 8, 'been': 124, 'resorted': 4, 'heads': 8, 'prominent': 8, 'museums': 4, 'passing': 4, 'ninety': 4, 'two': 48, 'recalled': 4, 'many': 20, 'locally': 4, 'interest': 24, 'intensified': 8, 'obscurity': 4, 'cause': 12, 'stricken': 8, 'whilst': 48, 'returning': 4, 'newport': 4, 'boat': 16, 'falling': 12, 'suddenly': 20, 'witnesses': 4, 'said': 64, 'after': 96, 'having': 36, 'jostled': 4, 'nautical': 4, 'looking': 16, 'negro': 12, 'who': 84, 'come': 64, 'queer': 32, 'courts': 4, 'precipitous': 4, 'hillside': 4, 'formed': 28, 'short': 12, 'cut': 16, 'waterfront': 16, 'deceased': 4, "'s": 236, 'home': 20, 'williams': 4, 'street': 28, 'physicians': 8, 'were': 199, 'unable': 4, 'find': 16, 'any': 64, 'visible': 16, 'disorder': 8, 'concluded': 4, 'perplexed': 4, 'debate': 4, 'obscure': 8, 'lesion': 4, 'heart': 12, 'induced': 8, 'brisk': 4, 'ascent': 4, 'steep': 4, 'hill' ...

# %% [markdown]
# ### 2 - Preprocesamiento completo
# Debemos realizar los mismos pasos que en el ejemplo anterior, pero antes de eso debemos transformar ese dataset de filas de oraciones en un texto completo continuo para poder extraer el vocabulario.

# %%
# Vistazo a las primeras filas
df.loc[:15,0]
# Out:
# 0    'THE CALL OF CTHULHU By H.P. LOVECRAFT THE CAL...
# Name: 0, dtype: object

# %%
# Concatenamos todos los rows en un solo valor
corpus = df.apply(lambda row: ' '.join(row.values.astype(str)), axis=0)[0]
corpus
# Out:
# '\'THE CALL OF CTHULHU By H.P. LOVECRAFT THE CALL OF CTHULHU Of such great powers or beings there may be conceivably a survival... a survival of a hugely remote period when... consciousness was manifested, perhaps, in shapes and forms long since withdrawn before the tide of advancing humanity... forms of which poetry and legend alone have caught a flying memory and called them gods, monsters, mythical beings of all sorts and kinds... — Algernon Blackwood PART I. THE HORROR IN CLAY The most merciful thing in the world, I think, is the inability of the human mind to correlate all its contents. We live on a placid island of ignorance in the midst of black seas of infinity, and it was not meant that we should voyage far. The sciences, each straining in its own direction, have hitherto harmed us little; but some day the piecing together of dissociated knowledge will open up such terrifying vistas of reality, and of our frightful position therein, that we shall either go mad from the revelation or flee from the light into the peace and safety of a new dark age. Theosophists have guessed at the awesome grandeur of the cosmic cycle wherein our world and human race form transient incidents. They have hinted at strange survivals in terms which would freeze the blood if not masked by a bland optimism. But it is not from them that there came the single glimpse of forbidden eons which chills me when I think of it and maddens me when I dream of it. That glimpse, like all dread glimpses of truth, flashed out from an accidental piecing together of separated things—in this case an old newspaper item and the notes of a dead professor. I hope that no one else will accomplish this piecing out; certainly, if I live, I shall never knowingly supply a link in so hideous a chain. I think that the professor, too intended to keep silent regarding the part he knew, and that he would have destroyed his notes had not sudden death seized him. My knowledge of the thing began in the winter of 1926-27 with the death of my great-uncle, George Gammell Angell, Professor Emeritus of Semitic Languages in Brown University, Providence, Rhode Island. Professor Angell was widely known as an authority on ancient inscriptions, and had frequently been resorted to by the heads of prominent museums; so that his passing at the age of ninety-two may be recalled by many. Locally, interest was intensified by the obscurity of the cause of death. The professor had been stricken whilst returning from the Newport boat; falling suddenly; as witnesses said, after having been jostled by a nautical-looking negro who had come from one of the queer dark courts on the precipitous hillside which formed a short cut from the waterfront to the deceased\\\'s home in Williams Street. Physicians were unable to find any visible disorder, but concluded after perplexed debate that some obscure lesion of the heart, induced by the brisk ascent of so steep a hill by so elderly a man, was responsible for the end. At the time I saw no reason to dissent from this dictum, but latterly I am inclined to wonder—and more than wonder. As my great-uncle\\\'s heir and executor, for he died a childless widower, I was expected to go over his papers with some thoroughness; and for that purpose moved his entire set of files and boxes to my quarters in Boston. Much of the material which I correlated will be later published by the American Archaeological Society, but there was one box which I found exceedingly puzzling, and which I felt much averse from showing to other eyes. It had been locked and I did not find the key till it occurred to me to examine the personal ring which the professor carried in his pocket. Then, indeed, I succeeded in opening it, but when I did so seemed only to be confronted by a greater and more closely locked barrier. For what could be the meaning of the queer clay bas-relief and the disjointed jottings, ramblings, and cuttings which I found? Had my uncle, in his latter years become credulo ...

# %%
# Transformar el corpus a tokens
tokens=text_to_word_sequence(corpus)
# Vistazo general de los primeros tokens
tokens[:20]
# Out:
# ["'the",
#  'call',
#  'of',
#  'cthulhu',
#  'by',
#  'h',
#  'p',
#  'lovecraft',
#  'the',
#  'call',
#  'of',
#  'cthulhu',
#  'of',
#  'such',
#  'great',
#  'powers',
#  'or',
#  'beings',
#  'there',
#  'may']

# %%
print("Cantidad de tokens en el corpus:", len(tokens))
# Out:
# Cantidad de tokens en el corpus: 12015

# %%
# Código para hacer el desfazaje de las palabras
# según el train_len
text_sequences = []
for i in range(train_len, len(tokens)):
  seq = tokens[i-train_len:i]
  text_sequences.append(seq)

# %%
# Demos un vistazo a nuestros vectores para entrenar el modelo
text_sequences[:20]
# Out:
# [["'the", 'call', 'of', 'cthulhu'],
#  ['call', 'of', 'cthulhu', 'by'],
#  ['of', 'cthulhu', 'by', 'h'],
#  ['cthulhu', 'by', 'h', 'p'],
#  ['by', 'h', 'p', 'lovecraft'],
#  ['h', 'p', 'lovecraft', 'the'],
#  ['p', 'lovecraft', 'the', 'call'],
#  ['lovecraft', 'the', 'call', 'of'],
#  ['the', 'call', 'of', 'cthulhu'],
#  ['call', 'of', 'cthulhu', 'of'],
#  ['of', 'cthulhu', 'of', 'such'],
#  ['cthulhu', 'of', 'such', 'great'],
#  ['of', 'such', 'great', 'powers'],
#  ['such', 'great', 'powers', 'or'],
#  ['great', 'powers', 'or', 'beings'],
#  ['powers', 'or', 'beings', 'there'],
#  ['or', 'beings', 'there', 'may'],
#  ['beings', 'there', 'may', 'be'],
#  ['there', 'may', 'be', 'conceivably'],
#  ['may', 'be', 'conceivably', 'a']]

# %%
# Proceso de tokenizacion
tok = Tokenizer()
tok.fit_on_texts(text_sequences)

# Convertimos las palabras a números
# entran palabras -> salen números
sequences = tok.texts_to_sequences(text_sequences)

# Damos un vistazo
sequences[:20]
# Out:
# [[3155, 454, 2, 58],
#  [454, 2, 58, 21],
#  [2, 58, 21, 682],
#  [58, 21, 682, 683],
#  [21, 682, 683, 1201],
#  [682, 683, 1201, 1],
#  [683, 1201, 1, 454],
#  [1201, 1, 454, 2],
#  [1, 454, 2, 58],
#  [454, 2, 58, 2],
#  [2, 58, 2, 135],
#  [58, 2, 135, 44],
#  [2, 135, 44, 1202],
#  [135, 44, 1202, 32],
#  [44, 1202, 32, 684],
#  [1202, 32, 684, 42],
#  [32, 684, 42, 136],
#  [684, 42, 136, 30],
#  [42, 136, 30, 1203],
#  [136, 30, 1203, 4]]

# %%
print("Cantidad de rows del dataset:", len(sequences))
# Out:
# Cantidad de rows del dataset: 12011

# %% [markdown]
# ### 3 - Input y target

# %%
# Con numpy es muy fácil realizar el slicing de vectores
ex = np.array([[1,2,3,4],[5,6,7,8]])
ex
# Out:
# array([[1, 2, 3, 4],
#        [5, 6, 7, 8]])

# %%
# Con numpy es muy fácil realizar el slicing de vectores
print("Dimension:", ex.shape)
print("Todos los elementos:", ex)
print("Todos los elementos menos el último:", ex[:, :-1])
# Out:
# Dimension: (2, 4)
# Todos los elementos: [[1 2 3 4]
#  [5 6 7 8]]
# Todos los elementos menos el último: [[1 2 3]
#  [5 6 7]]

# %%
input = ex[:,:-1] # todos los rows, menos la ultima col
target = ex[:, -1] # última col de cada row

print("Input:", input)
print("Target:", target)
# Out:
# Input: [[1 2 3]
#  [5 6 7]]
# Target: [4 8]

# %%
arr_sequences = np.array(sequences)
x_data = arr_sequences[:,:-1]
y_data_int = arr_sequences[:,-1] # aún falta el oneHotEncoder

print(x_data.shape)
print(y_data_int.shape)
# Out:
# (12011, 3)
# (12011,)

# %%
# Palabras del vocabulario
tok.index_word
# Out:
# {1: 'the',
#  2: 'of',
#  3: 'and',
#  4: 'a',
#  5: 'in',
#  6: 'to',
#  7: 'was',
#  8: 'had',
#  9: 'that',
#  10: 'i',
#  11: 'it',
#  12: 'he',
#  13: 'his',
#  14: 'which',
#  15: 'with',
#  16: 'from',
#  17: 'for',
#  18: 'on',
#  19: 'at',
#  20: 'as',
#  21: 'by',
#  22: 'but',
#  23: "'s",
#  24: 'not',
#  25: 'this',
#  26: 'my',
#  27: 'were',
#  28: 'all',
#  29: 'an',
#  30: 'be',
#  31: 'they',
#  32: 'or',
#  33: 'have',
#  34: 'its',
#  35: 'some',
#  36: 'could',
#  37: 'one',
#  38: 'no',
#  39: 'cult',
#  40: 'their',
#  41: 'men',
#  42: 'there',
#  43: 'what',
#  44: 'great',
#  45: 'professor',
#  46: 'so',
#  47: 'them',
#  48: 'old',
#  49: 'been',
#  50: 'only',
#  51: 'when',
#  52: 'him',
#  53: 'is',
#  54: 'would',
#  55: 'uncle',
#  56: 'now',
#  57: 'johansen',
#  58: 'cthulhu',
#  59: 'more',
#  60: 'dreams',
#  61: 'after',
#  62: 'man',
#  63: 'then',
#  64: 'wilcox',
#  65: 'out',
#  66: 'legrasse',
#  67: 'before',
#  68: 'me',
#  69: 'found',
#  70: 'thing',
#  71: 'who',
#  72: 'than',
#  73: 'told',
#  74: 'time',
#  75: 'very',
#  76: 'strange',
#  77: 'like',
#  78: 'dream',
#  79: 'earth',
#  80: 'into',
#  81: 'came',
#  82: 'must',
#  83: 'stone',
#  84: 'up',
#  85: 'never',
#  86: 'said',
#  87: 'come',
#  88: 'any',
#  89: 'about',
#  90: 'even',
#  91: 'made',
#  92: 'those',
#  93: 'angell',
#  94: 'young',
#  95: 'city',
#  96: 'ones',
#  97: 'stars',
#  98: 'dead',
#  99: 'known',
#  100: 'over',
#  101: 'though',
#  102: 'first',
#  103: 'upon',
#  104: 'again',
#  105: 'world',
#  106: 'dark',
#  107: 'if',
#  108: 'much',
#  109: 'did',
#  110: 'sea',
#  111: 'part',
#  112: 'black',
#  113: 'far',
#  114: 'will',
#  115: 'new',
#  116: 'too',
#  117: 'two',
#  118: 'whilst',
#  119: 'seemed',
#  120: 'bas',
#  121: 'r',
#  122: 'half',
#  123: 'march',
#  124: 'through',
#  125: 'april',
#  126: 'down',
#  127: 'alert',
#  128: 'think',
#  129: 'notes',
#  130: 'other',
#  131: 'relief',
#  132: 'sculptor',
#  133: 'manuscript',
#  134: 'something',
#  135: 'such',
#  136: 'may',
#  137: 'long',
#  138: 'day',
#  139: 'death',
#  140: 'began',
#  141: 'ancient',
#  142: 'felt',
#  143: 'indeed',
#  144: 'these',
#  145: 'night',
#  146: 'terrible',
#  147: "'lyeh",
#  148: 'once',
#  149: 'image',
#  150: 'still',
#  151: 'her',
#  152: 'shall',
#  153: 'hideous',
#  154: 'knew',
#  155: 'having',
#  156: 'way',
#  157: 'inspector',
#  158: 'enough',
#  159: 'green',
#  160: 'almost',
#  161: 'whose',
#  162: 'ever',
#  163: 'where',
#  164: 'unknown',
#  165: 'castro',
#  166: 'yacht',
#  167: 'emma',
#  168: 'most',
#  169: 'island',
#  170: 'queer',
#  171: 'saw',
#  172: 'died',
#  173: 'years',
#  174: 'head',
#  175: 'tale',
#  176: 'during',
#  177: 'went',
#  178: 'heard',
#  179: 'police',
#  180: 'back',
#  181: 'swamp',
#  182: 'under',
#  183: 'crew',
#  184: 'alone',
#  185: 'horror',
#  186: 'little',
#  187: 'mad',
#  188: 'formed',
#  189: 'street',
#  190: 'end',
#  191: 'material',
#  192: 'cuttings',
#  193: 'cyclopean',
#  194: 'second',
#  195: 'webb',
#  196: 'secret',
#  197: 'can',
#  198: 'without',
#  199: 'see',
#  200: 'has',
#  201: 'idol',
#  202: 'nothing',
#  203: 'might',
#  204: 'around',
#  205: 'prisoners',
#  206: 'right',
#  207: 'thought',
#  208: 'storm',
#  209: 'door',
#  210: 'since',
#  211: 'mind',
#  212: 'go',
#  213: 'cosmic',
#  214: 'form',
#  215: 'interest',
#  216: 'papers',
#  217: 'set',
#  218: 'do',
#  219: 'writing',
#  220: 'hieroglyphics',
#  221: 'body',
#  222: 'wings',
#  223: 'whole',
#  224: 'rest',
#  225: 'hidden',
#  226: 'excited',
#  227: 'bore',
#  228: 'himself',
#  229: 'showed',
#  230: 'place',
#  231: 'learned',
#  232: 'things',
#  233: 'every',
#  234: 'well',
#  235: 'here',
#  236: 'really',
#  237: 'know',
#  238: 'being',
#  239: 'toward',
#  240: 'full',
#  241: 'seen',
#  242: 'meeting',
#  243: 'members',
#  244: 'sight',
#  245: 'because',
#  246: 'vast',
#  247: 'monstrous',
#  248: 'ritual',
#  249: 'beyond',
#  250: 'monolith',
#  251: 'lay',
#  252: 'beneath',
#  253: 'talked',
#  254: 'sydney',
#  255: 'dunedin',
#  256: "'",
#  257: 'mate',
#  258: 'admiralty',
#  259: 'period',
#  260: 'memory',
#  261: 'called',
#  262: 'human',
#  263: 'together',
#  264: 'knowledge',
#  265: 'our',
#  266: 'age',
#  267: 'many',
#  268: 'suddenly',
#  269: 'home',
#  270: 'wonder',
#  271: 'later',
#  272: 'society',
#  273: 'till',
#  274: 'ring',
#  275: 'six',
#  276: 'origin',
#  277: 'although',
#  278: 'are',
#  279: 'figure',
#  280: 'monster',
#  281: 'orleans',
#  282: 'building',
#  283: 'odd',
#  284: 'spoke',
#  285: 'older',
#  286: 'sky',
#  287: 'fhtagn',
#  288: 'questions',
#  289: 'always',
#  290: 'several',
#  291: 'delirium',
#  292: 'apparently',
#  293: 'nameless',
#  294: 'three',
#  295: 'certain',
#  296: 'scattered',
#  297: 'least',
#  298: 'original',
#  299: 'between',
#  300: 'data',
#  301: 'subject',
#  302: 'date',
#  303: 'south',
#  304: 'white',
#  305: 'matters',
#  306: 'voodoo',
#  307: 'yet',
#  308: 'mystery',
#  309: 'esquimaux',
#  310: 'elder',
#  311: 'among',
#  312: 'squatters',
#  313: 'woods',
#  314: 'left',
#  315: 'away',
#  316: 'water',
#  317: 'carven',
#  318: 'course',
#  319: 'read',
#  320: 'sailed',
#  321: 'brought',
#  322: 'matter',
#  323: 'vigilant',
#  324: 'steam',
#  325: 'rock',
#  326: 'briden',
#  327: 'horrors',
#  328: 'visit',
#  329: 'clay',
#  330: 'we',
#  331: 'should',
#  332: 'voyage',
#  333: 'each',
#  334: 'own',
#  335: 'direction',
#  336: 'frightful',
#  337: 'dread',
#  338: 'case',
#  339: 'university',
#  340: 'providence',
#  341: 'boat',
#  342: 'looking',
#  343: 'cut',
#  344: 'waterfront',
#  345: 'find',
#  346: 'visible',
#  347: 'resolved',
#  348: 'less',
#  349: 'however',
#  350: 'wild',
#  351: 'despite',
#  352: 'failed',
#  353: 'imagination',
#  354: 'behind',
#  355: 's',
#  356: 'same',
#  357: 'w',
#  358: 'source',
#  359: 'mental',
#  360: 'group',
#  361: '1925',
#  362: '1st',
#  363: 'name',
#  364: 'slightly',
#  365: 'sculpture',
#  366: 'youth',
#  367: 'small',
#  368: 'ran',
#  369: 'asked',
#  370: 'anything',
#  371: 'recall',
#  372: 'last',
#  373: 'cities',
#  374: 'earthquake',
#  375: 'point',
#  376: 'sound',
#  377: 'letters',
#  378: 'frantic',
#  379: 'both',
#  380: 'repeated',
#  381: 'became',
#  382: 'convinced',
#  383: 'sounds',
#  384: 'continued',
#  385: 'fever',
#  386: 'taken',
#  387: 'kept',
#  388: 'high',
#  389: 'words',
#  390: 'visions',
#  391: 'gave',
#  392: 'nearly',
#  393: 'preserved',
#  394: 'cases',
#  395: 'mentioned',
#  396: 'february',
#  397: 'note',
#  398: 'number',
#  399: 'few',
#  400: 'given',
#  401: 'west',
#  402: 'experience',
#  403: 'held',
#  404: 'aged',
#  405: 'statuette',
#  406: 'wish',
#  407: 'captured',
#  408: 'rites',
#  409: 'apart',
#  410: 'eight',
#  411: 'height',
#  412: 'edge',
#  413: 'center',
#  414: 'life',
#  415: 'along',
#  416: 'mankind',
#  417: 'greenland',
#  418: 'devil',
#  419: 'worship',
#  420: 'aeons',
#  421: 'significance',
#  422: 'picture',
#  423: 'noted',
#  424: 'worshipers',
#  425: 'idols',
#  426: 'mongrel',
#  427: 'house',
#  428: 'tom',
#  429: 'begun',
#  430: 'stones',
#  431: 'none',
#  432: 'evil',
#  433: 'die',
#  434: 'themselves',
#  435: 'rise',
#  436: 'natural',
#  437: 'flame',
#  438: 'bodies',
#  439: 'trip',
#  440: 'waters',
#  441: 'universe',
#  442: 'sensitive',
#  443: 'mention',
#  444: 'instant',
#  445: 'museum',
#  446: 'survivor',
#  447: 'auckland',
#  448: 'landed',
#  449: 'vice',
#  450: 'oslo',
#  451: 'god',
#  452: 'sun',
#  453: 'ship',
#  454: 'call',
#  455: 'perhaps',
#  456: 'shapes',
#  457: 'live',
#  458: 'meant',
#  459: 'piecing',
#  460: 'vistas',
#  461: 'reality',
#  462: 'guessed',
#  463: 'hinted',
#  464: 'blood',
#  465: 'glimpse',
#  466: 'else',
#  467: 'keep',
#  468: 'widely',
#  469: 'cause',
#  470: 'falling',
#  471: 'negro',
#  472: 'short',
#  473: 'heart',
#  474: 'hill',
#  475: 'reason',
#  476: 'moved',
#  477: 'quarters',
#  478: 'exceedingly',
#  479: 'eyes',
#  480: 'personal',
#  481: 'carried',
#  482: 'latter',
#  483: 'apparent',
#  484: 'rough',
#  485: 'five',
#  486: 'often',
#  487: 'cryptic',
#  488: 'bulk',
#  489: 'hint',
#  490: 'remotest',
#  491: 'affiliations',
#  492: 'above',
#  493: 'clear',
#  494: 'sort',
#  495: 'fancy',
#  496: 'somewhat',
#  497: 'dragon',
#  498: 'grotesque',
#  499: 'scaly',
#  500: 'general',
#  501: 'vague',
#  502: 'aside',
#  503: 'document',
#  504: 'characters',
#  505: 'word',
#  506: 'work',
#  507: 'st',
#  508: 'brief',
#  509: 'largely',
#  510: 'spring',
#  511: 'appears',
#  512: 'aspect',
#  513: 'singular',
#  514: 'family',
#  515: 'design',
#  516: 'living',
#  517: 'genius',
#  518: 'art',
#  519: 'record',
#  520: 'rambling',
#  521: 'affected',
#  522: 'titan',
#  523: 'blocks',
#  524: 'monoliths',
#  525: 'dripping',
#  526: 'ooze',
#  527: 'voice',
#  528: 'questioned',
#  529: 'silence',
#  530: 'ignorant',
#  531: 'nocturnal',
#  532: '23',
#  533: 'inquiries',
#  534: 'revealed',
#  535: 'artists',
#  536: 'close',
#  537: 'whom',
#  538: 'dreamed',
#  539: 'touched',
#  540: 'fully',
#  541: 'described',
#  542: 'object',
#  543: 'occasional',
#  544: 'monstrosity',
#  545: 'oddly',
#  546: 'returned',
#  547: 'dreaming',
#  548: 'thoughts',
#  549: 'various',
#  550: 'seems',
#  551: 'received',
#  552: 'responses',
#  553: 'correspondence',
#  554: 'significant',
#  555: 'impressions',
#  556: 'description',
#  557: 'loose',
#  558: 'suspected',
#  559: 'corroboration',
#  560: 'somehow',
#  561: 'fear',
#  562: 'architect',
#  563: 'insane',
#  564: 'investigation',
#  565: 'reach',
#  566: 'london',
#  567: 'leaped',
#  568: 'speak',
#  569: 'weird',
#  570: 'hellish',
#  571: 'horrible',
#  572: 'took',
#  573: 'stumbled',
#  574: 'totally',
#  575: 'hence',
#  576: 'air',
#  577: 'dim',
#  578: 'greenish',
#  579: 'slowly',
#  580: 'face',
#  581: 'mass',
#  582: 'feelers',
#  583: 'claws',
#  584: 'feet',
#  585: 'narrow',
#  586: 'pedestal',
#  587: 'front',
#  588: 'type',
#  589: 'shape',
#  590: 'just',
#  591: 'tell',
#  592: 'proved',
#  593: 'phrase',
#  594: 'common',
#  595: 'priests',
#  596: 'chanted',
#  597: 'waits',
#  598: 'story',
#  599: 'castes',
#  600: 'good',
#  601: 'within',
#  602: 'soul',
#  603: 'frightened',
#  604: 'dank',
#  605: 'length',
#  606: 'ahead',
#  607: 'intervals',
#  608: 'endless',
#  609: 'whispered',
#  610: 'winged',
#  611: 'nightmare',
#  612: 'madness',
#  613: 'reached',
#  614: 'spot',
#  615: 'trees',
#  616: 'stood',
#  617: 'spawn',
#  618: 'top',
#  619: 'deeper',
#  620: 'suppose',
#  621: 'actually',
#  622: 'line',
#  623: 'carefully',
#  624: 'lived',
#  625: 'places',
#  626: 'mighty',
#  627: 'ready',
#  628: 'faithful',
#  629: 'whether',
#  630: 'others',
#  631: 'done',
#  632: 'gained',
#  633: 'remains',
#  634: 'images',
#  635: 'force',
#  636: 'outside',
#  637: 'making',
#  638: 'kill',
#  639: 'shadow',
#  640: 'forth',
#  641: 'deep',
#  642: 'authorities',
#  643: 'give',
#  644: 'amidst',
#  645: 'turned',
#  646: 'curiosity',
#  647: 'let',
#  648: 'soon',
#  649: 'slimy',
#  650: 'geometry',
#  651: 'sure',
#  652: 'seaman',
#  653: 'heaven',
#  654: 'eye',
#  655: 'desperate',
#  656: 'inquiry',
#  657: '12th',
#  658: 'latitude',
#  659: 'longitude',
#  660: '2nd',
#  661: 'says',
#  662: 'cabin',
#  663: 'norwegian',
#  664: 'schooner',
#  665: 'order',
#  666: 'put',
#  667: 'wife',
#  668: 'court',
#  669: 'awful',
#  670: 'cannot',
#  671: 'against',
#  672: 'masonry',
#  673: 'angles',
#  674: 'distorted',
#  675: 'fright',
#  676: 'looked',
#  677: 'donovan',
#  678: 'everyone',
#  679: 'poor',
#  680: 'laughing',
#  681: 'books',
#  682: 'h',
#  683: 'p',
#  684: 'beings',
#  685: 'survival',
#  686: 'remote',
#  687: 'consciousness',
#  688: 'manifested',
#  689: 'forms',
#  690: 'poetry',
#  691: 'legend',
#  692: 'caught',
#  693: 'gods',
#  694: '—',
#  695: 'contents',
#  696: 'infinity',
#  697: 'hitherto',
#  698: 'position',
#  699: 'either',
#  700: 'light',
#  701: 'peace',
#  702: 'theosophists',
#  703: 'awesome',
#  704: 'cycle',
#  705: 'wherein',
#  706: 'transient',
#  707: 'incidents',
#  708: 'single',
#  709: 'glimpses',
#  710: 'truth',
#  711: 'item',
#  712: 'hope',
#  713: 'certainly',
#  714: 'link',
#  715: 'regarding',
#  716: '1926',
#  717: 'rhode',
#  718: 'authority',
#  719: 'inscriptions',
#  720: 'frequently',
#  721: 'heads',
#  722: 'prominent',
#  723: 'intensified',
#  724: 'stricken',
#  725: 'physicians',
#  726: 'disorder',
#  727: 'obscure',
#  728: 'induced',
#  729: 'responsible',
#  730: 'latterly',
#  731: 'am',
#  732: 'expected',
#  733: 'thoroughness',
#  734: 'entire',
#  735: 'american',
#  736: 'archaeological',
#  737: 'box',
#  738: 'locked',
#  739: 'key',
#  740: 'succeeded',
#  741: 'greater',
#  742: 'become',
#  743: 'search',
#  744: 'inch',
#  745: 'inches',
#  746: 'area',
#  747: 'modern',
#  748: 'designs',
#  749: 'suggestion',
#  750: 'futurism',
#  751: 'kind',
#  752: 'particular',
#  753: 'pictorial',
#  754: 'idea',
#  755: 'nature',
#  756: 'symbol',
#  757: 'say',
#  758: 'octopus',
#  759: 'outline',
#  760: 'press',
#  761: 'recent',
#  762: 'hand',
#  763: 'headed',
#  764: 'reading',
#  765: 'thomas',
#  766: 'narrative',
#  767: 'john',
#  768: 'la',
#  769: '1908',
#  770: 'accounts',
#  771: 'persons',
#  772: 'theosophical',
#  773: 'lost',
#  774: 'societies',
#  775: 'cults',
#  776: 'references',
#  777: 'anthropological',
#  778: 'golden',
#  779: 'witch',
#  780: 'mania',
#  781: 'damp',
#  782: 'recognized',
#  783: 'excellent',
#  784: 'studying',
#  785: 'school',
#  786: 'lys',
#  787: 'near',
#  788: 'eccentricity',
#  789: 'commercial',
#  790: 'merely',
#  791: 'esthetes',
#  792: 'quite',
#  793: 'host',
#  794: 'manner',
#  795: 'suggested',
#  796: 'tablet',
#  797: 'kinship',
#  798: 'impressed',
#  799: 'make',
#  800: 'verbatim',
#  801: 'poetic',
#  802: 'highly',
#  803: 'brooding',
#  804: 'babylon',
#  805: 'slight',
#  806: 'england',
#  807: 'flung',
#  808: 'sinister',
#  809: 'covered',
#  810: 'walls',
#  811: 'pillars',
#  812: 'sensation',
#  813: 'attempted',
#  814: 'jumble',
#  815: 'scientific',
#  816: 'studied',
#  817: 'intensity',
#  818: 'chilled',
#  819: 'stolen',
#  820: 'visitor',
#  821: 'especially',
#  822: 'tried',
#  823: 'promises',
#  824: 'lore',
#  825: 'demands',
#  826: 'future',
#  827: 'reports',
#  828: 'regular',
#  829: 'daily',
#  830: 'related',
#  831: 'intelligence',
#  832: 'shouting',
#  833: 'sense',
#  834: 'save',
#  835: 'rendered',
#  836: 'appear',
#  837: 'forward',
#  838: 'calling',
#  839: 'dr',
#  840: 'tobey',
#  841: 'charge',
#  842: 'doctor',
#  843: 'gigantic',
#  844: 'miles',
#  845: 'walked',
#  846: 'lumbered',
#  847: 'identical',
#  848: 'sought',
#  849: 'added',
#  850: 'condition',
#  851: 'otherwise',
#  852: 'suggest',
#  853: 'true',
#  854: 'rather',
#  855: '2',
#  856: 'ceased',
#  857: 'completely',
#  858: 'happened',
#  859: '22',
#  860: 'week',
#  861: 'thoroughly',
#  862: 'forming',
#  863: 'account',
#  864: 'question',
#  865: 'amongst',
#  866: 'friends',
#  867: 'dates',
#  868: 'people',
#  869: 'traditional',
#  870: 'result',
#  871: 'formless',
#  872: 'four',
#  873: 'abnormal',
#  874: 'poets',
#  875: 'panic',
#  876: 'broken',
#  877: 'able',
#  878: 'leading',
#  879: 'why',
#  880: 'feel',
#  881: 'imposing',
#  882: 'scientist',
#  883: 'bizarre',
#  884: 'reported',
#  885: 'confessed',
#  886: 'acute',
#  887: 'describes',
#  888: 'sad',
#  889: 'months',
#  890: 'incessant',
#  891: 'escaped',
#  892: 'hell',
#  893: 'instead',
#  894: 'wondered',
#  895: 'questioning',
#  896: 'puzzled',
#  897: 'cutting',
#  898: 'bureau',
#  899: 'window',
#  900: 'shocking',
#  901: 'cry',
#  902: 'likewise',
#  903: 'paper',
#  904: 'america',
#  905: 'theosophist',
#  906: 'glorious',
#  907: 'arrives',
#  908: 'native',
#  909: 'legendry',
#  910: 'named',
#  911: 'recorded',
#  912: 'stopped',
#  913: 'conclusions',
#  914: 'scarcely',
#  915: 'rationalism',
#  916: 'outlines',
#  917: 'syllables',
#  918: 'stirring',
#  919: 'connection',
#  920: 'outsiders',
#  921: 'expert',
#  922: 'special',
#  923: 'local',
#  924: 'prompted',
#  925: 'fetish',
#  926: 'whatever',
#  927: 'unbelievable',
#  928: 'absolutely',
#  929: 'discovered',
#  930: 'track',
#  931: 'assembled',
#  932: 'excitement',
#  933: 'utter',
#  934: 'strangeness',
#  935: 'antiquity',
#  936: 'centuries',
#  937: 'careful',
#  938: 'study',
#  939: 'workmanship',
#  940: 'hind',
#  941: 'fore',
#  942: 'block',
#  943: 'crouching',
#  944: 'bottom',
#  945: 'huge',
#  946: 'incalculable',
#  947: 'show',
#  948: 'familiar',
#  949: 'equally',
#  950: 'present',
#  951: 'horribly',
#  952: 'unhallowed',
#  953: 'cycles',
#  954: 'gathering',
#  955: 'late',
#  956: 'william',
#  957: 'encountered',
#  958: 'religion',
#  959: 'curious',
#  960: 'faith',
#  961: 'rituals',
#  962: 'supreme',
#  963: 'priest',
#  964: 'best',
#  965: 'how',
#  966: 'suspense',
#  967: 'followed',
#  968: 'awed',
#  969: 'detective',
#  970: 'identity',
#  971: 'distance',
#  972: 'substance',
#  973: 'louisiana',
#  974: 'aloud',
#  975: 'ph',
#  976: "'nglui",
#  977: 'mglw',
#  978: "'nafh",
#  979: 'wgah',
#  980: "'nagl",
#  981: 'advance',
#  982: 'celebrants',
#  983: 'profound',
#  984: 'summons',
#  985: 'country',
#  986: 'terror',
#  987: 'disappeared',
#  988: 'beating',
#  989: 'haunted',
#  990: 'squatter',
#  991: 'morbid',
#  992: 'hysterical',
#  993: 'muffled',
#  994: 'toms',
#  995: 'glare',
#  996: 'refused',
#  997: 'another',
#  998: 'scene',
#  999: 'plunged',
#  1000: 'mortal',
#  ...}

# %%
# Cantidad de palabras en el vocabulario
vocab_size = len(tok.word_counts)

# %%
# Transformar los datos a oneHotEncoding
#y_data = to_categorical(y_data_int, num_classes=vocab_size)

# %%
# En el caso anterior explota porque y_data_int comienza en "1" en vez de "0"
# valor minimo:
min(y_data_int)
# Out:
# 1

# %%
y_data_int_offset = y_data_int - 1
y_data = to_categorical(y_data_int_offset, num_classes=vocab_size)
y_data.shape
# Out:
# (12011, 3156)

# %% [markdown]
# ### 4 - Entrenar el modelo

# %%
# largo de la secuencia de entrada
input_seq_len = x_data.shape[1]
input_seq_len
# Out:
# 3

# %%
# Largo del vector de salida --> vocab_size
output_size = vocab_size
output_size
# Out:
# 3156

# %%
model = Sequential()

# Embedding:
# input_seq_len = 3 --> ingreso 3 palabras
# input_dim = vocab_size --> 1628 palabras distintas
# output_dim = 5 --> crear embeddings de tamaño 3 (tamaño variable y ajustable)
model.add(Embedding(input_dim=vocab_size+1, output_dim=5, input_length=input_seq_len))

#model.add(LSTM(64, return_sequences=True))
#model.add(Dropout(0.2))
model.add(LSTM(64)) # La última capa LSTM no lleva return_sequences
model.add(Dense(32, activation='relu'))

# Predicción de clasificación con softmax
# La salida vuelve al espacio de 1628 palabras posibles
model.add(Dense(vocab_size, activation='softmax'))

# Clasificación multiple categórica --> loss = categorical_crossentropy
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 3, 5)              15785
#
#  lstm_1 (LSTM)               (None, 64)                17920
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dense_3 (Dense)             (None, 3156)              104148
#
# =================================================================
# Total params: 139,933
# Trainable params: 139,933
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(x_data, y_data, epochs=750, validation_split=0.2)
# Out:
# Epoch 1/750
# 301/301 [==============================] - 14s 35ms/step - loss: 7.0602 - accuracy: 0.0598 - val_loss: 6.9834 - val_accuracy: 0.0753
# Epoch 2/750
# 301/301 [==============================] - 3s 11ms/step - loss: 6.4947 - accuracy: 0.0645 - val_loss: 7.1273 - val_accuracy: 0.0753
# Epoch 3/750
# 301/301 [==============================] - 3s 11ms/step - loss: 6.3940 - accuracy: 0.0645 - val_loss: 7.2167 - val_accuracy: 0.0753
# Epoch 4/750
# 301/301 [==============================] - 3s 10ms/step - loss: 6.2663 - accuracy: 0.0645 - val_loss: 7.3574 - val_accuracy: 0.0753
# Epoch 5/750
# 301/301 [==============================] - 2s 8ms/step - loss: 6.1587 - accuracy: 0.0645 - val_loss: 7.4416 - val_accuracy: 0.0753
# Epoch 6/750
# 301/301 [==============================] - 3s 9ms/step - loss: 6.0745 - accuracy: 0.0703 - val_loss: 7.7186 - val_accuracy: 0.0757
# Epoch 7/750
# 301/301 [==============================] - 2s 8ms/step - loss: 5.9975 - accuracy: 0.0768 - val_loss: 7.7366 - val_accuracy: 0.0787
# Epoch 8/750
# 301/301 [==============================] - 3s 10ms/step - loss: 5.9104 - accuracy: 0.0837 - val_loss: 7.9793 - val_accuracy: 0.0803
# Epoch 9/750
750
# 301/301 [==============================] - 3s 9ms/step - loss: 0.1699 - accuracy: 0.9506 - val_loss: 91.5687 - val_accuracy: 0.0279
# Epoch 749/750
# 301/301 [==============================] - 3s 9ms/step - loss: 0.1593 - accuracy: 0.9511 - val_loss: 92.7283 - val_accuracy: 0.0270
# Epoch 750/750
# 301/301 [==============================] - 4s 12ms/step - loss: 0.1649 - accuracy: 0.9517 - val_loss: 92.0237 - val_accuracy: 0.0270

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Entrenamiento
epoch_count = range(1, len(hist.history['accuracy']) + 1)
sns.lineplot(x=epoch_count,  y=hist.history['accuracy'], label='train')
sns.lineplot(x=epoch_count,  y=hist.history['val_accuracy'], label='valid')
plt.show()

# %% [markdown]
# ### 5 - Predicción de próxima palabra

# %%
# Keras pad_sequences
# https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/sequence/pad_sequences
# Si la secuencia de entrada supera al input_seq_len (3) se trunca
# Si la secuencia es más corta se agregna ceros al comienzo

# %%
# Se utilizará gradio para ensayar el modelo
# Herramienta poderosa para crear interfaces rápidas para ensayar modelos
# https://gradio.app/
import sys
# !{sys.executable} -m pip install gradio --quiet

# %% [markdown]
# ### 6 - Generación de secuencias nuevas

# %%
def generate_seq(model, tokenizer, seed_text, max_length, n_words):
    """
        Exec model sequence prediction

        Args:
            model (keras): modelo entrenado
            tokenizer (keras tokenizer): tonenizer utilizado en el preprocesamiento
            seed_text (string): texto de entrada (input_seq)
            max_length (int): máxima longitud de la sequencia de entrada
            n_words (int): números de palabras a agregar a la sequencia de entrada
        returns:
            output_text (string): sentencia con las "n_words" agregadas
    """
    output_text = seed_text
	# generate a fixed number of words
    for _ in range(n_words):
		# Encodeamos
        encoded = tokenizer.texts_to_sequences([output_text])[0]
		# Si tienen distinto largo
        encoded = pad_sequences([encoded], maxlen=max_length, padding='pre')

		# Predicción softmax
        y_hat = model.predict(encoded).argmax(axis=-1)
		# Vamos concatenando las predicciones
        out_word = ''

        # Debemos buscar en el vocabulario la palabra
        # que corresopnde al indice (y_hat) predicho por le modelo
        for word, index in tokenizer.word_index.items():
            if index == y_hat:
                out_word = word
                break

		# Agrego las palabras a la frase predicha
        output_text += ' ' + out_word
    return output_text

# %%
input_text='the sea is'

generate_seq(model, tok, input_text, max_length=3, n_words=8)
# Out:
# 1/1 [==============================] - 0s 393ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 'the sea is or carven showed with three only on the'

# %% [markdown]
# ###Conclusiones
# El modelo entrenado tuvo un muy mal desempeño en el entrenamiento además de overfitting. Cuestiones que podrían mejorarse:
# - Agregar más capas o neuronaes
# - Agregar BRNN
#
# Para casos donde los epochs son menores, tenemos mas información, ya que no existió un sobre ajuste, y para "the sea is" con 750 epochs tenemos que resulta "the sea is i door    ", a diferencia que con 50 epochs que obtenemos "the sea is legrasse's fore architectural when he found had questions  ", ambos con n_words = 8. Apesar de obtener accuracy mas alto para 750 epochs, el sobreajuste es demasiado alto:
#
# 750 EPOCHS:
# ![750epochs.PNG](data:image/png;base64,...)
#
#
# 50 EPOCHS:
# ![50epochs.PNG](data:image/png;base64,...)
#
# Es importante otras tecnicas de embedding para texto, vemos que apesar de usar 50 epochs y obtener un buen resutaldo, puede parecer sin sentido por el accuracy de validación, nos dice que el modelo solo predice bien con datos de entrenamiento.
